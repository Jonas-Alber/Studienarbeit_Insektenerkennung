# %% [markdown]
# # Initialisation

# %% [markdown]
# ## GPU Status Check

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
import tensorflow as tf
import timeit

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

def cpu():
  with tf.device('/cpu:0'):
    random_image_cpu = tf.random.normal((100, 100, 100, 3))
    net_cpu = tf.keras.layers.Conv2D(32, 7)(random_image_cpu)
    return tf.math.reduce_sum(net_cpu)

def gpu():
  with tf.device('/device:GPU:0'):
    random_image_gpu = tf.random.normal((100, 100, 100, 3))
    net_gpu = tf.keras.layers.Conv2D(32, 7)(random_image_gpu)
    return tf.math.reduce_sum(net_gpu)
  
# We run each op once to warm up; see: https://stackoverflow.com/a/45067900
cpu()
gpu()

# Run the op several times.
print('Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images '
      '(batch x height x width x channel). Sum of ten runs.')
print('CPU (s):')
cpu_time = timeit.timeit('cpu()', number=10, setup="from __main__ import cpu")
print(cpu_time)
print('GPU (s):')
gpu_time = timeit.timeit('gpu()', number=10, setup="from __main__ import gpu")
print(gpu_time)
print('GPU speedup over CPU: {}x'.format(int(cpu_time/gpu_time)))
# Out:
# Time (s) to convolve 32x7x7x3 filter over random 100x100x100x3 images (batch x height x width x channel). Sum of ten runs.
# CPU (s):
# 2.9396087669999815
# GPU (s):
# 0.037407722000011745
# GPU speedup over CPU: 78x

# %% [markdown]
# ## Requirements Installation

# %% [markdown]
# Cloning TFOD 2.0 Github

# %%
cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# Cloning into 'models'...
# remote: Enumerating objects: 81085, done.
# remote: Counting objects: 100% (622/622), done.
# remote: Compressing objects: 100% (298/298), done.
# remote: Total 81085 (delta 393), reused 526 (delta 321), pack-reused 80463
# Receiving objects: 100% (81085/81085), 596.11 MiB | 18.44 MiB/s, done.
# Resolving deltas: 100% (57734/57734), done.

# %%
cd /content/models/research
# Out:
# /content/models/research

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 20.92 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
cd cocoapi/PythonAPI
# Out:
# /content/models/research/cocoapi/PythonAPI

# %%
# !make
# Out:
# python setup.py build_ext --inplace
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.8/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/models/research/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-3.8
# creating build/temp.linux-x86_64-3.8/pycocotools
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.8/dist-packages/numpy/core/include -I../common -I/usr/include/python3.8 -c ../common/maskApi.c -o build/temp.linux-x86_64-3.8/../common/maskApi.o -Wno-cpp -Wno-unused-function -std=c99
# ../common/maskApi.c: In function ‘rleDecode’:
# ../common/maskApi.c:46:7: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#    46 |       for( k=0; k<R[i].cnts[j]; k++ ) *(M++)=v; v=!v; }}
#       |       ^~~
# ../common/maskApi.c:46:49: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#    46 |       for( k=0; k<R[i].cnts[j]; k++ ) *(M++)=v; v=!v; }}
#       |                                                 ^
# ../common/maskApi.c: In function ‘rleFrPoly’:
# ../common/maskApi.c:166:3: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   166 |   for(j=0; j<k; j++) x[j]=(int)(scale*xy[j*2+0]+.5); x[k]=x[0];
#       |   ^~~
# ../common/maskApi.c:166:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   166 |   for(j=0; j<k; j++) x[j]=(int)(scale*xy[j*2+0]+.5); x[k]=x[0];
#       |                                                      ^
# ../common/maskApi.c:167:3: warning: this ‘for’ clause does not guard... [-Wmisleading-indentation]
#   167 |   for(j=0; j<k; j++) y[j]=(int)(scale*xy[j*2+1]+.5); y[k]=y[0];
#       |   ^~~
# ../common/maskApi.c:167:54: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘for’
#   167 |   for(j=0; j<k; j++) y[j]=(int)(scale*xy[j*2+1]+.5); y[k]=y[0];
#       |                                                      ^
# ../common/maskApi.c: In function ‘rleToString’:
# ../common/maskApi.c:212:7: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   212 |       if(more) c |= 0x20; c+=48; s[p++]=c;
#       |       ^~
# ../common/maskApi.c:212:27: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   212 |       if(more) c |= 0x20; c+=48; s[p++]=c;
#       |                           ^
# ../common/maskApi.c: In function ‘rleFrString’:
# ../common/maskApi.c:220:3: warning: this ‘while’ clause does not guard... [-Wmisleading-indentation]
#   220 |   while( s[m] ) m++; cnts=malloc(sizeof(uint)*m); m=0;
#       |   ^~~~~
# ../common/maskApi.c:220:22: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘while’
#   220 |   while( s[m] ) m++; cnts=malloc(sizeof(uint)*m); m=0;
#       |                      ^~~~
# ../common/maskApi.c:228:5: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#   228 |     if(m>2) x+=(long) cnts[m-2]; cnts[m++]=(uint) x;
#       |     ^~
# ../common/maskApi.c:228:34: note: ...this statement, but the latter is misleadingly indented as if it were guarded by the ‘if’
#   228 |     if(m>2) x+=(long) cnts[m-2]; cnts[m++]=(uint) x;
#       |                                  ^~~~
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.8/dist-packages/numpy/core/include -I../common -I/usr/include/python3.8 -c pycocotools/_mask.c -o build/temp.linux-x86_64-3.8/pycocotools/_mask.o -Wno-cpp -Wno-unused-function -std=c99
# creating build/lib.linux-x86_64-3.8
# creating build/lib.linux-x86_64-3.8/pycocotools
# x86_64-linux-gnu-gcc -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fwrapv -O2 -Wl,-Bsymbolic-functions -Wl,-z,relro -g -fwrapv -O2 -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 build/temp.linux-x86_64-3.8/../common/maskApi.o build/temp.linux-x86_64-3.8/pycocotools/_mask.o -o build/lib.linux-x86_64-3.8/pycocotools/_mask.cpython-38-x86_64-linux-gnu.so
# copying build/lib.linux-x86_64-3.8/pycocotools/_mask.cpython-38-x86_64-linux-gnu.so -> pycocotools
# rm -rf build

# %%
cp -r pycocotools /content/models/research

# %% [markdown]
# Install the Object Detection API

# %%
cd /content/models/research
# Out:
# /content/models/research

# %%
cp object_detection/packages/tf2/setup.py .

# %%
# !python -m pip install --use-feature=2020-resolver .
# Out:
# WARNING: --use-feature=2020-resolver no longer has any effect, since it is now the default dependency resolver in pip. This will become an error in pip 21.0.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/models/research
#   Preparing metadata (setup.py) ... done
# Collecting avro-python3
#   Downloading avro-python3-1.10.2.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Collecting apache-beam
#   Downloading apache_beam-2.44.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 89.4 MB/s eta 0:00:00
# Requirement already satisfied: pillow in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (7.1.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (4.9.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (3.2.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (0.29.33)
# Requirement already satisfied: contextlib2 in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (0.5.5)
# Collecting tf-slim
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.1/352.1 KB 38.6 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (1.15.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (2.0.6)
# Collecting lvis
#   Downloading lvis-0.5.3-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (1.7.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (1.3.5)
# Collecting tf-models-official>=2.5.1
#   Downloading tf_models_official-2.11.3-py2.py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 14.1 MB/s eta 0:00:00
# Collecting tensorflow_io
#   Downloading tensorflow_io-0.30.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 61.9 MB/s eta 0:00:00
# Requirement already satisfied: keras in /usr/local/lib/python3.8/dist-packages (from object-detection==0.1) (2.9.0)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 9.8 MB/s eta 0:00:00
# Collecting sacrebleu<=2.2.0
#   Downloading sacrebleu-2.2.0-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.6/116.6 KB 17.1 MB/s eta 0:00:00
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.8/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (0.8.10)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from sacrebleu<=2.2.0->object-detection==0.1) (1.21.6)
# Collecting pyyaml<6.0,>=5.1
#   Downloading PyYAML-5.4.1-cp38-cp38-manylinux1_x86_64.whl (662 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.4/662.4 KB 59.1 MB/s eta 0:00:00
# Collecting immutabledict
#   Downloading immutabledict-2.2.3-py3-none-any.whl (4.0 kB)
# Collecting tensorflow~=2.11.0
#   Downloading tensorflow-2.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.8.2)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (1.5.12)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.7 MB/s eta 0:00:00
# Requirement already satisfied: gin-config in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.5.0)
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 KB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (5.4.8)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (0.12.0)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.1.3)
# Collecting tensorflow-model-optimization>=0.4.1
#   Downloading tensorflow_model_optimization-0.7.3-py2.py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.9/238.9 KB 32.1 MB/s eta 0:00:00
# Collecting py-cpuinfo>=3.3.0
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (4.7.0.68)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.8/dist-packages (from tf-models-official>=2.5.1->object-detection==0.1) (2.70.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 74.4 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.11.0
#   Downloading tensorflow_text-2.11.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 93.8 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->object-detection==0.1) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->object-detection==0.1) (2.8.2)
# Requirement already satisfied: absl-py>=0.2.2 in /usr/local/lib/python3.8/dist-packages (from tf-slim->object-detection==0.1) (1.4.0)
# Requirement already satisfied: pyarrow<10.0.0,>=0.15.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (9.0.0)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (1.51.1)
# Requirement already satisfied: cloudpickle~=2.2.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (2.2.1)
# Collecting hdfs<3.0.0,>=2.1.0
#   Downloading hdfs-2.7.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (1.22.2)
# Collecting orjson<4.0
#   Downloading orjson-3.8.5-cp38-cp38-manylinux_2_28_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 KB 20.0 MB/s eta 0:00:00
# Requirement already satisfied: pydot<2,>=1.2.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (1.3.0)
# Collecting fastavro<2,>=0.23.6
#   Downloading fastavro-1.7.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 97.9 MB/s eta 0:00:00
# Requirement already satisfied: httplib2<0.21.0,>=0.8 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (0.17.4)
# Collecting objsize<0.7.0,>=0.6.1
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Collecting zstandard<1,>=0.18.0
#   Downloading zstandard-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 105.9 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (2.25.1)
# Collecting fasteners<1.0,>=0.3
#   Downloading fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (1.7)
# Requirement already satisfied: typing-extensions>=3.7.0 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (4.4.0)
# Requirement already satisfied: protobuf<4,>3.12.2 in /usr/local/lib/python3.8/dist-packages (from apache-beam->object-detection==0.1) (3.19.6)
# Collecting dill<0.3.2,>=0.3.1.1
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 KB 21.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pymongo<4.0.0,>=3.8.0
#   Downloading pymongo-3.13.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.2/526.2 KB 52.9 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from lvis->object-detection==0.1) (1.4.4)
# Requirement already satisfied: opencv-python>=4.1.0.25 in /usr/local/lib/python3.8/dist-packages (from lvis->object-detection==0.1) (4.6.0.66)
# Requirement already satisfied: cycler>=0.10.0 in /usr/local/lib/python3.8/dist-packages (from lvis->object-detection==0.1) (0.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem==0.30.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow_io->object-detection==0.1) (0.30.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (4.1.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.16.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (2.11.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.8/dist-packages (from google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (0.1.0)
# Collecting docopt
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (8.0.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (4.64.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.24.0->apache-beam->object-detection==0.1) (4.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (23.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (15.0.6.1)
# Collecting keras
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 83.1 MB/s eta 0:00:00
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.6.3)
# Collecting tensorboard<2.12,>=2.11
#   Downloading tensorboard-2.11.2-py3-none-any.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 94.9 MB/s eta 0:00:00
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (2.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (57.4.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 KB 40.4 MB/s eta 0:00:00
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-23.1.21-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official>=2.5.1->object-detection==0.1) (0.1.8)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.8/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.2.8)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.8/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (0.4.8)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from oauth2client->tf-models-official>=2.5.1->object-detection==0.1) (4.9)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.8/dist-packages (from seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.0.2)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons->tf-models-official>=2.5.1->object-detection==0.1) (2.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (7.1.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (2.3)
# Requirement already satisfied: toml in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (0.10.2)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.0.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (5.10.2)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.8/dist-packages (from tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (1.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.38.4)
# Requirement already satisfied: zipp in /usr/local/lib/python3.8/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official>=2.5.1->object-detection==0.1) (3.12.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.8/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (1.58.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official>=2.5.1->object-detection==0.1) (5.3.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official>=2.5.1->object-detection==0.1) (1.2.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.0.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.8/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official>=2.5.1->object-detection==0.1) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (6.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow~=2.11.0->tf-models-official>=2.5.1->object-detection==0.1) (3.2.2)
# Building wheels for collected packages: object-detection, avro-python3, dill, seqeval, docopt
#   Building wheel for object-detection (setup.py) ... done
#   Created wheel for object-detection: filename=object_detection-0.1-py3-none-any.whl size=1696777 sha256=53e4f63ce890ad1357b4a97aa3b2b960bce1780bc750c325da5bec3a40f730b3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-zjgi5kzk/wheels/7d/96/c1/072a751379735e8dfdada1def1c62a89afb3cc45654fd6fd28
#   Building wheel for avro-python3 (setup.py) ... done
#   Created wheel for avro-python3: filename=avro_python3-1.10.2-py3-none-any.whl size=44009 sha256=e61c88588fec5c29af871c3165cf62a4d456d5e7a63cf32d8e889463534c22c9
#   Stored in directory: /root/.cache/pip/wheels/bb/73/e9/d273421f5723c4bf544dcf9eb097bda94421ef8d3252699f0a
#   Building wheel for dill (setup.py) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78544 sha256=e2fc7259e5ce405696c88934187552214b6a97a14096fdf19ee4c08e4eaa6609
#   Stored in directory: /root/.cache/pip/wheels/07/35/78/e9004fa30578734db7f10e7a211605f3f0778d2bdde38a239d
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16179 sha256=97e27120701a4d6934ce08db83a886cf0b931a9c8ee8260936f8cc6a3bcc85bd
#   Stored in directory: /root/.cache/pip/wheels/ad/5c/ba/05fa33fa5855777b7d686e843ec07452f22a66a138e290e732
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13723 sha256=a4945d535b29921eed9fbb7873ce02e873caf7e122bbe848cf3ea79184c36dee
#   Stored in directory: /root/.cache/pip/wheels/56/ea/58/ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built object-detection avro-python3 dill seqeval docopt
# Installing collected packages: sentencepiece, py-cpuinfo, flatbuffers, docopt, zstandard, tf-slim, tensorflow-model-optimization, tensorflow_io, tensorflow-estimator, tensorflow-addons, pyyaml, pyparsing, pymongo, portalocker, orjson, objsize, keras, immutabledict, fasteners, fastavro, dill, colorama, avro-python3, sacrebleu, hdfs, seqeval, lvis, apache-beam, tensorboard, tensorflow, tensorflow-text, tf-models-official, object-detection
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
#     Uninstalling flatbuffers-1.12:
#       Successfully uninstalled flatbuffers-1.12
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.3.3
#     Uninstalling pymongo-4.3.3:
#       Successfully uninstalled pymongo-4.3.3
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.6
#     Uninstalling dill-0.3.6:
#       Successfully uninstalled dill-0.3.6
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.9.2
#     Uninstalling tensorflow-2.9.2:
#       Successfully uninstalled tensorflow-2.9.2
# Successfully installed apache-beam-2.44.0 avro-python3-1.10.2 colorama-0.4.6 dill-0.3.1.1 docopt-0.6.2 fastavro-1.7.1 fasteners-0.18 flatbuffers-23.1.21 hdfs-2.7.0 immutabledict-2.2.3 keras-2.11.0 lvis-0.5.3 object-detection-0.1 objsize-0.6.1 orjson-3.8.5 portalocker-2.7.0 py-cpuinfo-9.0.0 pymongo-3.13.0 pyparsing-2.4.7 pyyaml-5.4.1 sacrebleu-2.2.0 sentencepiece-0.1.97 seqeval-1.2.2 tensorboard-2.11.2 tensorflow-2.11.0 tensorflow-addons-0.19.0 tensorflow-estimator-2.11.0 tensorflow-model-optimization-0.7.3 tensorflow-text-2.11.0 tensorflow_io-0.30.0 tf-models-official-2.11.3 tf-slim-1.1.0 zstandard-0.19.0

# %%
# From within TensorFlow/models/research/
# !python object_detection/builders/model_builder_tf2_test.py
# Out:
# 2023-02-06 12:32:21.796612: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-06 12:32:22.935066: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-06 12:32:22.935200: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-06 12:32:22.935220: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Running tests under Python 3.8.10: /usr/bin/python3
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_deepmac
# 2023-02-06 12:32:28.011862: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# W0206 12:32:28.274585 139659708988480 model_builder.py:1112] Building experimental DeepMAC meta-arch. Some features may be omitted.
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.35s
# I0206 12:32:28.541954 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_deepmac): 1.35s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_deepmac
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.64s
# I0206 12:32:29.179021 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)): 0.64s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model0 (customize_head_params=True)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.27s
# I0206 12:32:29.452796 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)): 0.27s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model1 (customize_head_params=False)
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.25s
# I0206 12:32:29.702183 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_from_keypoints): 0.25s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_from_keypoints
# [ RUN      ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.87s
# I0206 12:32:31.570681 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_center_net_model_mobilenet): 1.87s
# [       OK ] ModelBuilderTF2Test.test_create_center_net_model_mobilenet
# [ RUN      ] ModelBuilderTF2Test.test_create_experimental_model
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# I0206 12:32:31.576003 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_experimental_model): 0.0s
# [       OK ] ModelBuilderTF2Test.test_create_experimental_model
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# I0206 12:32:31.600227 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature0 (True)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# I0206 12:32:31.616467 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_from_config_with_crop_feature1 (False)
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# I0206 12:32:31.633150 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner): 0.02s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_model_from_config_with_example_miner
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.24s
# I0206 12:32:31.876244 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul): 0.24s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.09s
# I0206 12:32:31.969076 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_faster_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.1s
# I0206 12:32:32.064790 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_with_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.09s
# I0206 12:32:32.158811 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul): 0.09s
# [       OK ] ModelBuilderTF2Test.test_create_faster_rcnn_models_from_config_mask_rcnn_without_matmul
# [ RUN      ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.1s
# I0206 12:32:32.261332 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_rfcn_model_from_config): 0.1s
# [       OK ] ModelBuilderTF2Test.test_create_rfcn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# I0206 12:32:32.290028 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config): 0.03s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_fpn_model_from_config
# [ RUN      ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# I0206 12:32:32.464527 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b0
# I0206 12:32:32.464687 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 64
# I0206 12:32:32.464755 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 3
# I0206 12:32:32.467830 139659708988480 efficientnet_model.py:143] round_filter input=32 output=32
# I0206 12:32:32.496692 139659708988480 efficientnet_model.py:143] round_filter input=32 output=32
# I0206 12:32:32.496819 139659708988480 efficientnet_model.py:143] round_filter input=16 output=16
# I0206 12:32:32.568020 139659708988480 efficientnet_model.py:143] round_filter input=16 output=16
# I0206 12:32:32.568172 139659708988480 efficientnet_model.py:143] round_filter input=24 output=24
# I0206 12:32:32.755803 139659708988480 efficientnet_model.py:143] round_filter input=24 output=24
# I0206 12:32:32.755997 139659708988480 efficientnet_model.py:143] round_filter input=40 output=40
# I0206 12:32:32.934589 139659708988480 efficientnet_model.py:143] round_filter input=40 output=40
# I0206 12:32:32.934768 139659708988480 efficientnet_model.py:143] round_filter input=80 output=80
# I0206 12:32:33.199277 139659708988480 efficientnet_model.py:143] round_filter input=80 output=80
# I0206 12:32:33.199467 139659708988480 efficientnet_model.py:143] round_filter input=112 output=112
# I0206 12:32:33.473613 139659708988480 efficientnet_model.py:143] round_filter input=112 output=112
# I0206 12:32:33.473809 139659708988480 efficientnet_model.py:143] round_filter input=192 output=192
# I0206 12:32:33.814835 139659708988480 efficientnet_model.py:143] round_filter input=192 output=192
# I0206 12:32:33.815004 139659708988480 efficientnet_model.py:143] round_filter input=320 output=320
# I0206 12:32:33.896347 139659708988480 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0206 12:32:33.935956 139659708988480 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.0, resolution=224, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0206 12:32:33.985236 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b1
# I0206 12:32:33.985407 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 88
# I0206 12:32:33.985482 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 4
# I0206 12:32:33.987028 139659708988480 efficientnet_model.py:143] round_filter input=32 output=32
# I0206 12:32:34.004654 139659708988480 efficientnet_model.py:143] round_filter input=32 output=32
# I0206 12:32:34.004759 139659708988480 efficientnet_model.py:143] round_filter input=16 output=16
# I0206 12:32:34.158419 139659708988480 efficientnet_model.py:143] round_filter input=16 output=16
# I0206 12:32:34.158618 139659708988480 efficientnet_model.py:143] round_filter input=24 output=24
# I0206 12:32:34.416446 139659708988480 efficientnet_model.py:143] round_filter input=24 output=24
# I0206 12:32:34.416604 139659708988480 efficientnet_model.py:143] round_filter input=40 output=40
# I0206 12:32:34.660613 139659708988480 efficientnet_model.py:143] round_filter input=40 output=40
# I0206 12:32:34.660784 139659708988480 efficientnet_model.py:143] round_filter input=80 output=80
# I0206 12:32:34.989726 139659708988480 efficientnet_model.py:143] round_filter input=80 output=80
# I0206 12:32:34.989901 139659708988480 efficientnet_model.py:143] round_filter input=112 output=112
# I0206 12:32:35.325933 139659708988480 efficientnet_model.py:143] round_filter input=112 output=112
# I0206 12:32:35.326090 139659708988480 efficientnet_model.py:143] round_filter input=192 output=192
# I0206 12:32:35.746351 139659708988480 efficientnet_model.py:143] round_filter input=192 output=192
# I0206 12:32:35.746531 139659708988480 efficientnet_model.py:143] round_filter input=320 output=320
# I0206 12:32:35.916095 139659708988480 efficientnet_model.py:143] round_filter input=1280 output=1280
# I0206 12:32:35.947625 139659708988480 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.0, depth_coefficient=1.1, resolution=240, dropout_rate=0.2, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0206 12:32:36.004977 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b2
# I0206 12:32:36.005121 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 112
# I0206 12:32:36.005188 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 5
# I0206 12:32:36.006742 139659708988480 efficientnet_model.py:143] round_filter input=32 output=32
# I0206 12:32:36.023786 139659708988480 efficientnet_model.py:143] round_filter input=32 output=32
# I0206 12:32:36.023929 139659708988480 efficientnet_model.py:143] round_filter input=16 output=16
# I0206 12:32:36.155632 139659708988480 efficientnet_model.py:143] round_filter input=16 output=16
# I0206 12:32:36.155805 139659708988480 efficientnet_model.py:143] round_filter input=24 output=24
# I0206 12:32:36.416315 139659708988480 efficientnet_model.py:143] round_filter input=24 output=24
# I0206 12:32:36.416494 139659708988480 efficientnet_model.py:143] round_filter input=40 output=48
# I0206 12:32:36.852224 139659708988480 efficientnet_model.py:143] round_filter input=40 output=48
# I0206 12:32:36.852401 139659708988480 efficientnet_model.py:143] round_filter input=80 output=88
# I0206 12:32:37.195218 139659708988480 efficientnet_model.py:143] round_filter input=80 output=88
# I0206 12:32:37.195386 139659708988480 efficientnet_model.py:143] round_filter input=112 output=120
# I0206 12:32:37.554327 139659708988480 efficientnet_model.py:143] round_filter input=112 output=120
# I0206 12:32:37.554501 139659708988480 efficientnet_model.py:143] round_filter input=192 output=208
# I0206 12:32:37.983380 139659708988480 efficientnet_model.py:143] round_filter input=192 output=208
# I0206 12:32:37.983546 139659708988480 efficientnet_model.py:143] round_filter input=320 output=352
# I0206 12:32:38.156796 139659708988480 efficientnet_model.py:143] round_filter input=1280 output=1408
# I0206 12:32:38.191367 139659708988480 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.1, depth_coefficient=1.2, resolution=260, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0206 12:32:38.248580 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b3
# I0206 12:32:38.248725 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 160
# I0206 12:32:38.248793 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 6
# I0206 12:32:38.250330 139659708988480 efficientnet_model.py:143] round_filter input=32 output=40
# I0206 12:32:38.269526 139659708988480 efficientnet_model.py:143] round_filter input=32 output=40
# I0206 12:32:38.269637 139659708988480 efficientnet_model.py:143] round_filter input=16 output=24
# I0206 12:32:38.419175 139659708988480 efficientnet_model.py:143] round_filter input=16 output=24
# I0206 12:32:38.419338 139659708988480 efficientnet_model.py:143] round_filter input=24 output=32
# I0206 12:32:38.678102 139659708988480 efficientnet_model.py:143] round_filter input=24 output=32
# I0206 12:32:38.678261 139659708988480 efficientnet_model.py:143] round_filter input=40 output=48
# I0206 12:32:38.928448 139659708988480 efficientnet_model.py:143] round_filter input=40 output=48
# I0206 12:32:38.928608 139659708988480 efficientnet_model.py:143] round_filter input=80 output=96
# I0206 12:32:39.366719 139659708988480 efficientnet_model.py:143] round_filter input=80 output=96
# I0206 12:32:39.366875 139659708988480 efficientnet_model.py:143] round_filter input=112 output=136
# I0206 12:32:39.800390 139659708988480 efficientnet_model.py:143] round_filter input=112 output=136
# I0206 12:32:39.800558 139659708988480 efficientnet_model.py:143] round_filter input=192 output=232
# I0206 12:32:40.315667 139659708988480 efficientnet_model.py:143] round_filter input=192 output=232
# I0206 12:32:40.315839 139659708988480 efficientnet_model.py:143] round_filter input=320 output=384
# I0206 12:32:40.502084 139659708988480 efficientnet_model.py:143] round_filter input=1280 output=1536
# I0206 12:32:40.542801 139659708988480 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.2, depth_coefficient=1.4, resolution=300, dropout_rate=0.3, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0206 12:32:40.601114 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b4
# I0206 12:32:40.601278 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 224
# I0206 12:32:40.601353 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0206 12:32:40.602935 139659708988480 efficientnet_model.py:143] round_filter input=32 output=48
# I0206 12:32:40.621982 139659708988480 efficientnet_model.py:143] round_filter input=32 output=48
# I0206 12:32:40.622125 139659708988480 efficientnet_model.py:143] round_filter input=16 output=24
# I0206 12:32:40.770041 139659708988480 efficientnet_model.py:143] round_filter input=16 output=24
# I0206 12:32:40.770198 139659708988480 efficientnet_model.py:143] round_filter input=24 output=32
# I0206 12:32:41.096468 139659708988480 efficientnet_model.py:143] round_filter input=24 output=32
# I0206 12:32:41.096633 139659708988480 efficientnet_model.py:143] round_filter input=40 output=56
# I0206 12:32:41.448337 139659708988480 efficientnet_model.py:143] round_filter input=40 output=56
# I0206 12:32:41.448507 139659708988480 efficientnet_model.py:143] round_filter input=80 output=112
# I0206 12:32:41.949917 139659708988480 efficientnet_model.py:143] round_filter input=80 output=112
# I0206 12:32:41.950078 139659708988480 efficientnet_model.py:143] round_filter input=112 output=160
# I0206 12:32:42.473756 139659708988480 efficientnet_model.py:143] round_filter input=112 output=160
# I0206 12:32:42.473940 139659708988480 efficientnet_model.py:143] round_filter input=192 output=272
# I0206 12:32:43.360356 139659708988480 efficientnet_model.py:143] round_filter input=192 output=272
# I0206 12:32:43.360526 139659708988480 efficientnet_model.py:143] round_filter input=320 output=448
# I0206 12:32:43.541676 139659708988480 efficientnet_model.py:143] round_filter input=1280 output=1792
# I0206 12:32:43.576217 139659708988480 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.4, depth_coefficient=1.8, resolution=380, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0206 12:32:43.643701 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b5
# I0206 12:32:43.643850 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 288
# I0206 12:32:43.643946 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 7
# I0206 12:32:43.645524 139659708988480 efficientnet_model.py:143] round_filter input=32 output=48
# I0206 12:32:43.662431 139659708988480 efficientnet_model.py:143] round_filter input=32 output=48
# I0206 12:32:43.662550 139659708988480 efficientnet_model.py:143] round_filter input=16 output=24
# I0206 12:32:43.856614 139659708988480 efficientnet_model.py:143] round_filter input=16 output=24
# I0206 12:32:43.856770 139659708988480 efficientnet_model.py:143] round_filter input=24 output=40
# I0206 12:32:44.269978 139659708988480 efficientnet_model.py:143] round_filter input=24 output=40
# I0206 12:32:44.270139 139659708988480 efficientnet_model.py:143] round_filter input=40 output=64
# I0206 12:32:44.700522 139659708988480 efficientnet_model.py:143] round_filter input=40 output=64
# I0206 12:32:44.700691 139659708988480 efficientnet_model.py:143] round_filter input=80 output=128
# I0206 12:32:45.287161 139659708988480 efficientnet_model.py:143] round_filter input=80 output=128
# I0206 12:32:45.287320 139659708988480 efficientnet_model.py:143] round_filter input=112 output=176
# I0206 12:32:45.884987 139659708988480 efficientnet_model.py:143] round_filter input=112 output=176
# I0206 12:32:45.885152 139659708988480 efficientnet_model.py:143] round_filter input=192 output=304
# I0206 12:32:46.652181 139659708988480 efficientnet_model.py:143] round_filter input=192 output=304
# I0206 12:32:46.652360 139659708988480 efficientnet_model.py:143] round_filter input=320 output=512
# I0206 12:32:46.916588 139659708988480 efficientnet_model.py:143] round_filter input=1280 output=2048
# I0206 12:32:46.953950 139659708988480 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.6, depth_coefficient=2.2, resolution=456, dropout_rate=0.4, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0206 12:32:47.032754 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b6
# I0206 12:32:47.032940 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0206 12:32:47.033010 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0206 12:32:47.034616 139659708988480 efficientnet_model.py:143] round_filter input=32 output=56
# I0206 12:32:47.054414 139659708988480 efficientnet_model.py:143] round_filter input=32 output=56
# I0206 12:32:47.054536 139659708988480 efficientnet_model.py:143] round_filter input=16 output=32
# I0206 12:32:47.262328 139659708988480 efficientnet_model.py:143] round_filter input=16 output=32
# I0206 12:32:47.262488 139659708988480 efficientnet_model.py:143] round_filter input=24 output=40
# I0206 12:32:47.767670 139659708988480 efficientnet_model.py:143] round_filter input=24 output=40
# I0206 12:32:47.767834 139659708988480 efficientnet_model.py:143] round_filter input=40 output=72
# I0206 12:32:48.276673 139659708988480 efficientnet_model.py:143] round_filter input=40 output=72
# I0206 12:32:48.276836 139659708988480 efficientnet_model.py:143] round_filter input=80 output=144
# I0206 12:32:48.957574 139659708988480 efficientnet_model.py:143] round_filter input=80 output=144
# I0206 12:32:48.957737 139659708988480 efficientnet_model.py:143] round_filter input=112 output=200
# I0206 12:32:49.882735 139659708988480 efficientnet_model.py:143] round_filter input=112 output=200
# I0206 12:32:49.882919 139659708988480 efficientnet_model.py:143] round_filter input=192 output=344
# I0206 12:32:50.819611 139659708988480 efficientnet_model.py:143] round_filter input=192 output=344
# I0206 12:32:50.819775 139659708988480 efficientnet_model.py:143] round_filter input=320 output=576
# I0206 12:32:51.075042 139659708988480 efficientnet_model.py:143] round_filter input=1280 output=2304
# I0206 12:32:51.109534 139659708988480 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=1.8, depth_coefficient=2.6, resolution=528, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# I0206 12:32:51.197496 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:150] EfficientDet EfficientNet backbone version: efficientnet-b7
# I0206 12:32:51.197650 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:152] EfficientDet BiFPN num filters: 384
# I0206 12:32:51.197721 139659708988480 ssd_efficientnet_bifpn_feature_extractor.py:153] EfficientDet BiFPN num iterations: 8
# I0206 12:32:51.199398 139659708988480 efficientnet_model.py:143] round_filter input=32 output=64
# I0206 12:32:51.218507 139659708988480 efficientnet_model.py:143] round_filter input=32 output=64
# I0206 12:32:51.218620 139659708988480 efficientnet_model.py:143] round_filter input=16 output=32
# I0206 12:32:51.494052 139659708988480 efficientnet_model.py:143] round_filter input=16 output=32
# I0206 12:32:51.494213 139659708988480 efficientnet_model.py:143] round_filter input=24 output=48
# I0206 12:32:52.090381 139659708988480 efficientnet_model.py:143] round_filter input=24 output=48
# I0206 12:32:52.090562 139659708988480 efficientnet_model.py:143] round_filter input=40 output=80
# I0206 12:32:52.686187 139659708988480 efficientnet_model.py:143] round_filter input=40 output=80
# I0206 12:32:52.686351 139659708988480 efficientnet_model.py:143] round_filter input=80 output=160
# I0206 12:32:53.512193 139659708988480 efficientnet_model.py:143] round_filter input=80 output=160
# I0206 12:32:53.512362 139659708988480 efficientnet_model.py:143] round_filter input=112 output=224
# I0206 12:32:54.339768 139659708988480 efficientnet_model.py:143] round_filter input=112 output=224
# I0206 12:32:54.339953 139659708988480 efficientnet_model.py:143] round_filter input=192 output=384
# I0206 12:32:55.423479 139659708988480 efficientnet_model.py:143] round_filter input=192 output=384
# I0206 12:32:55.423643 139659708988480 efficientnet_model.py:143] round_filter input=320 output=640
# I0206 12:32:55.802459 139659708988480 efficientnet_model.py:143] round_filter input=1280 output=2560
# I0206 12:32:55.841721 139659708988480 efficientnet_model.py:453] Building model efficientnet with params ModelConfig(width_coefficient=2.0, depth_coefficient=3.1, resolution=600, dropout_rate=0.5, blocks=(BlockConfig(input_filters=32, output_filters=16, kernel_size=3, num_repeat=1, expand_ratio=1, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=16, output_filters=24, kernel_size=3, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=24, output_filters=40, kernel_size=5, num_repeat=2, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=40, output_filters=80, kernel_size=3, num_repeat=3, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=80, output_filters=112, kernel_size=5, num_repeat=3, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=112, output_filters=192, kernel_size=5, num_repeat=4, expand_ratio=6, strides=(2, 2), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise'), BlockConfig(input_filters=192, output_filters=320, kernel_size=3, num_repeat=1, expand_ratio=6, strides=(1, 1), se_ratio=0.25, id_skip=True, fused_conv=False, conv_type='depthwise')), stem_base_filters=32, top_base_filters=1280, activation='simple_swish', batch_norm='default', bn_momentum=0.99, bn_epsilon=0.001, weight_decay=5e-06, drop_connect_rate=0.2, depth_divisor=8, min_depth=None, use_se=True, input_channels=3, num_classes=1000, model_name='efficientnet', rescale_input=False, data_format='channels_last', dtype='float32')
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 23.9s
# I0206 12:32:56.192322 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_create_ssd_models_from_config): 23.9s
# [       OK ] ModelBuilderTF2Test.test_create_ssd_models_from_config
# [ RUN      ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# I0206 12:32:56.218079 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_faster_rcnn_batchnorm_update
# [ RUN      ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# I0206 12:32:56.219712 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_first_stage_nms_iou_threshold
# [ RUN      ] ModelBuilderTF2Test.test_invalid_model_config_proto
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# I0206 12:32:56.220182 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_invalid_model_config_proto): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_model_config_proto
# [ RUN      ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# I0206 12:32:56.221469 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_invalid_second_stage_batch_size): 0.0s
# [       OK ] ModelBuilderTF2Test.test_invalid_second_stage_batch_size
# [ RUN      ] ModelBuilderTF2Test.test_session
# [  SKIPPED ] ModelBuilderTF2Test.test_session
# [ RUN      ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# I0206 12:32:56.222639 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_faster_rcnn_feature_extractor
# [ RUN      ] ModelBuilderTF2Test.test_unknown_meta_architecture
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# I0206 12:32:56.223050 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_unknown_meta_architecture): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_meta_architecture
# [ RUN      ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# INFO:tensorflow:time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# I0206 12:32:56.223918 139659708988480 test_util.py:2457] time(__main__.ModelBuilderTF2Test.test_unknown_ssd_feature_extractor): 0.0s
# [       OK ] ModelBuilderTF2Test.test_unknown_ssd_feature_extractor
# ----------------------------------------------------------------------
# Ran 24 tests in 29.033s
#
# OK (skipped=1)

# %% [markdown]
# ## Generate Record

# %%
cd /content/drive/MyDrive/tf_workspace
# Out:
# /content/drive/MyDrive/tf_workspace

# %%
# !python generate_tfrecord.py -x /content/drive/MyDrive/tf_workspace/training/images/train -l /content/drive/MyDrive/tf_workspace/training/annotations/label_map.pbtxt -o /content/drive/MyDrive/tf_workspace/training/annotations/train.record
# Out:
# Traceback (most recent call last):
#   File "generate_tfrecord.py", line 29, in <module>
#     from models.research.object_detection.utils import dataset_util, label_map_util
#   File "/content/drive/MyDrive/tf_workspace/models/research/object_detection/utils/label_map_util.py", line 29, in <module>
#     from object_detection.protos import string_int_label_map_pb2
# ModuleNotFoundError: No module named 'object_detection'

# %%
# !python generate_tfrecord.py -x /content/drive/MyDrive/tf_workspace/training/images/test -l /content/drive/MyDrive/tf_workspace/training/annotations/label_map.pbtxt -o /content/drive/MyDrive/tf_workspace/training/annotations/train.record
# Out:
# Traceback (most recent call last):
#   File "generate_tfrecord.py", line 29, in <module>
#     from object_detection.utils import dataset_util, label_map_util
# ModuleNotFoundError: No module named 'object_detection'

# %% [markdown]
# # Run and Export

# %% [markdown]
# ## Run Training

# %%
cd /content/drive/MyDrive/tf_workspace/training_demo
# Out:
# /content/drive/MyDrive/tf_workspace/training_demo

# %% [markdown]
# ``` !python model_main_tf2.py --model_dir=/content/drive/MyDrive/tf_workspace/training_demo/models/first_resnet101_v1_nn --pipeline_config_path=/content/drive/MyDrive/tf_workspace/training_demo/models/first_resnet101_v1_nn/pipeline.config ```

# %%
# !python model_main_tf2.py --model_dir=/content/drive/MyDrive/tf_workspace/training_demo/models/first_resnet101_v1_nn --pipeline_config_path=/content/drive/MyDrive/tf_workspace/training_demo/models/first_resnet101_v1_nn/pipeline.config
# Out:
# 2023-02-05 12:59:43.958389: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-05 12:59:45.181176: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-05 12:59:45.181294: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-05 12:59:45.181315: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-05 12:59:49.305434: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0205 12:59:49.321053 140002831592512 mirrored_strategy.py:374] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0205 12:59:49.327402 140002831592512 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0205 12:59:49.327579 140002831592512 config_util.py:552] Maybe overwriting use_bfloat16: False
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0205 12:59:49.353491 140002831592512 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/model_lib_v2.py:563: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['/content/drive/MyDrive/tf_workspace/training_demo/annotations/train.record']
# I0205 12:59:49.562476 140002831592512 dataset_builder.py:162] Reading unweighted datasets: ['/content/drive/MyDrive/tf_workspace/training_demo/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['/content/drive/MyDrive/tf_workspace/training_demo/annotations/train.record']
# I0205 12:59:49.562978 140002831592512 dataset_builder.py:79] Reading record datasets for input file: ['/content/drive/MyDrive/tf_workspace/training_demo/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0205 12:59:49.563130 140002831592512 dataset_builder.py:80] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0205 12:59:49.563217 140002831592512 dataset_builder.py:86] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# W0205 12:59:49.569253 140002831592512 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:100: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.deterministic`.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0205 12:59:49.587201 140002831592512 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/object_detection/builders/dataset_builder.py:235: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W0205 12:59:50.165895 140002831592512 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0205 12:59:55.718065 140002831592512 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0205 12:59:58.444444 140002831592512 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0205 13:00:00.151898 140002831592512 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/dispatch.py:1176: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# /usr/local/lib/python3.8/dist-packages/keras/backend.py:451: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn(
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0205 13:00:41.141569 140002831592512 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0205 13:00:41.144494 140002831592512 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0205 13:00:41.145713 140002831592512 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0205 13:00:41.146798 140002831592512 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0205 13:00:41.150555 140002831592512 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0205 13:00:41.151637 140002831592512 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0205 13:00:41.152741 140002831592512 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0205 13:00:41.153773 140002831592512 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0205 13:00:41.157568 140002831592512 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0205 13:00:41.158610 140002831592512 cross_device_ops.py:616] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# W0205 13:00:44.004140 139998485542656 deprecation.py:554] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/deprecation.py:629: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead
# INFO:tensorflow:Step 100 per-step time 1.241s
# I0205 13:02:47.745269 140002831592512 model_lib_v2.py:705] Step 100 per-step time 1.241s
# INFO:tensorflow:{'Loss/classification_loss': 0.4964022,
#  'Loss/localization_loss': 0.53274864,
#  'Loss/regularization_loss': 0.3017895,
#  'Loss/total_loss': 1.3309404,
#  'learning_rate': 0.014666351}
# I0205 13:02:47.745679 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.4964022,
#  'Loss/localization_loss': 0.53274864,
#  'Loss/regularization_loss': 0.3017895,
#  'Loss/total_loss': 1.3309404,
#  'learning_rate': 0.014666351}
# INFO:tensorflow:Step 200 per-step time 0.762s
# I0205 13:04:03.938405 140002831592512 model_lib_v2.py:705] Step 200 per-step time 0.762s
# INFO:tensorflow:{'Loss/classification_loss': 0.50366706,
#  'Loss/localization_loss': 0.40255368,
#  'Loss/regularization_loss': 0.30085355,
#  'Loss/total_loss': 1.2070743,
#  'learning_rate': 0.0159997}
# I0205 13:04:03.938735 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.50366706,
#  'Loss/localization_loss': 0.40255368,
#  'Loss/regularization_loss': 0.30085355,
#  'Loss/total_loss': 1.2070743,
#  'learning_rate': 0.0159997}
# INFO:tensorflow:Step 300 per-step time 0.760s
# I0205 13:05:19.888521 140002831592512 model_lib_v2.py:705] Step 300 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.4997497,
#  'Loss/localization_loss': 0.36501458,
#  'Loss/regularization_loss': 0.29974222,
#  'Loss/total_loss': 1.1645064,
#  'learning_rate': 0.01733305}
# I0205 13:05:19.888902 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.4997497,
#  'Loss/localization_loss': 0.36501458,
#  'Loss/regularization_loss': 0.29974222,
#  'Loss/total_loss': 1.1645064,
#  'learning_rate': 0.01733305}
# INFO:tensorflow:Step 400 per-step time 0.760s
# I0205 13:06:35.919752 140002831592512 model_lib_v2.py:705] Step 400 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.45330998,
#  'Loss/localization_loss': 0.43528423,
#  'Loss/regularization_loss': 0.29813156,
#  'Loss/total_loss': 1.1867257,
#  'learning_rate': 0.0186664}
# I0205 13:06:35.920106 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.45330998,
#  'Loss/localization_loss': 0.43528423,
#  'Loss/regularization_loss': 0.29813156,
#  'Loss/total_loss': 1.1867257,
#  'learning_rate': 0.0186664}
# INFO:tensorflow:Step 500 per-step time 0.760s
# I0205 13:07:51.919004 140002831592512 model_lib_v2.py:705] Step 500 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.4092911,
#  'Loss/localization_loss': 0.31224257,
#  'Loss/regularization_loss': 0.29589406,
#  'Loss/total_loss': 1.0174277,
#  'learning_rate': 0.01999975}
# I0205 13:07:51.919311 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.4092911,
#  'Loss/localization_loss': 0.31224257,
#  'Loss/regularization_loss': 0.29589406,
#  'Loss/total_loss': 1.0174277,
#  'learning_rate': 0.01999975}
# INFO:tensorflow:Step 600 per-step time 0.761s
# I0205 13:09:08.013226 140002831592512 model_lib_v2.py:705] Step 600 per-step time 0.761s
# INFO:tensorflow:{'Loss/classification_loss': 0.39656046,
#  'Loss/localization_loss': 0.31014243,
#  'Loss/regularization_loss': 0.2937461,
#  'Loss/total_loss': 1.000449,
#  'learning_rate': 0.0213331}
# I0205 13:09:08.013560 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.39656046,
#  'Loss/localization_loss': 0.31014243,
#  'Loss/regularization_loss': 0.2937461,
#  'Loss/total_loss': 1.000449,
#  'learning_rate': 0.0213331}
# INFO:tensorflow:Step 700 per-step time 0.762s
# I0205 13:10:24.187908 140002831592512 model_lib_v2.py:705] Step 700 per-step time 0.762s
# INFO:tensorflow:{'Loss/classification_loss': 0.5609795,
#  'Loss/localization_loss': 0.40637654,
#  'Loss/regularization_loss': 0.2915226,
#  'Loss/total_loss': 1.2588786,
#  'learning_rate': 0.02266645}
# I0205 13:10:24.188268 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.5609795,
#  'Loss/localization_loss': 0.40637654,
#  'Loss/regularization_loss': 0.2915226,
#  'Loss/total_loss': 1.2588786,
#  'learning_rate': 0.02266645}
# INFO:tensorflow:Step 800 per-step time 0.759s
# I0205 13:11:40.070264 140002831592512 model_lib_v2.py:705] Step 800 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.44019648,
#  'Loss/localization_loss': 0.34209257,
#  'Loss/regularization_loss': 0.28941953,
#  'Loss/total_loss': 1.0717086,
#  'learning_rate': 0.023999799}
# I0205 13:11:40.070599 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.44019648,
#  'Loss/localization_loss': 0.34209257,
#  'Loss/regularization_loss': 0.28941953,
#  'Loss/total_loss': 1.0717086,
#  'learning_rate': 0.023999799}
# INFO:tensorflow:Step 900 per-step time 0.760s
# I0205 13:12:56.101957 140002831592512 model_lib_v2.py:705] Step 900 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.3819358,
#  'Loss/localization_loss': 0.15195005,
#  'Loss/regularization_loss': 0.2869594,
#  'Loss/total_loss': 0.82084525,
#  'learning_rate': 0.025333151}
# I0205 13:12:56.102285 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.3819358,
#  'Loss/localization_loss': 0.15195005,
#  'Loss/regularization_loss': 0.2869594,
#  'Loss/total_loss': 0.82084525,
#  'learning_rate': 0.025333151}
# INFO:tensorflow:Step 1000 per-step time 0.760s
# I0205 13:14:12.147400 140002831592512 model_lib_v2.py:705] Step 1000 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.34362575,
#  'Loss/localization_loss': 0.20725773,
#  'Loss/regularization_loss': 0.284519,
#  'Loss/total_loss': 0.8354025,
#  'learning_rate': 0.0266665}
# I0205 13:14:12.147723 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.34362575,
#  'Loss/localization_loss': 0.20725773,
#  'Loss/regularization_loss': 0.284519,
#  'Loss/total_loss': 0.8354025,
#  'learning_rate': 0.0266665}
# INFO:tensorflow:Step 1100 per-step time 0.801s
# I0205 13:15:32.249851 140002831592512 model_lib_v2.py:705] Step 1100 per-step time 0.801s
# INFO:tensorflow:{'Loss/classification_loss': 0.36972904,
#  'Loss/localization_loss': 0.19907598,
#  'Loss/regularization_loss': 0.28186092,
#  'Loss/total_loss': 0.8506659,
#  'learning_rate': 0.02799985}
# I0205 13:15:32.250218 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.36972904,
#  'Loss/localization_loss': 0.19907598,
#  'Loss/regularization_loss': 0.28186092,
#  'Loss/total_loss': 0.8506659,
#  'learning_rate': 0.02799985}
# INFO:tensorflow:Step 1200 per-step time 0.760s
# I0205 13:16:48.265129 140002831592512 model_lib_v2.py:705] Step 1200 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.3033847,
#  'Loss/localization_loss': 0.18934684,
#  'Loss/regularization_loss': 0.27906576,
#  'Loss/total_loss': 0.7717973,
#  'learning_rate': 0.0293332}
# I0205 13:16:48.265453 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.3033847,
#  'Loss/localization_loss': 0.18934684,
#  'Loss/regularization_loss': 0.27906576,
#  'Loss/total_loss': 0.7717973,
#  'learning_rate': 0.0293332}
# INFO:tensorflow:Step 1300 per-step time 0.758s
# I0205 13:18:04.053594 140002831592512 model_lib_v2.py:705] Step 1300 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.35686612,
#  'Loss/localization_loss': 0.23932579,
#  'Loss/regularization_loss': 0.27687743,
#  'Loss/total_loss': 0.8730693,
#  'learning_rate': 0.03066655}
# I0205 13:18:04.053985 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.35686612,
#  'Loss/localization_loss': 0.23932579,
#  'Loss/regularization_loss': 0.27687743,
#  'Loss/total_loss': 0.8730693,
#  'learning_rate': 0.03066655}
# INFO:tensorflow:Step 1400 per-step time 0.759s
# I0205 13:19:19.933550 140002831592512 model_lib_v2.py:705] Step 1400 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.47091568,
#  'Loss/localization_loss': 0.42587098,
#  'Loss/regularization_loss': 0.274608,
#  'Loss/total_loss': 1.1713947,
#  'learning_rate': 0.0319999}
# I0205 13:19:19.933967 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.47091568,
#  'Loss/localization_loss': 0.42587098,
#  'Loss/regularization_loss': 0.274608,
#  'Loss/total_loss': 1.1713947,
#  'learning_rate': 0.0319999}
# INFO:tensorflow:Step 1500 per-step time 0.761s
# I0205 13:20:36.002979 140002831592512 model_lib_v2.py:705] Step 1500 per-step time 0.761s
# INFO:tensorflow:{'Loss/classification_loss': 0.41235724,
#  'Loss/localization_loss': 0.2830316,
#  'Loss/regularization_loss': 0.27202123,
#  'Loss/total_loss': 0.9674101,
#  'learning_rate': 0.03333325}
# I0205 13:20:36.003331 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.41235724,
#  'Loss/localization_loss': 0.2830316,
#  'Loss/regularization_loss': 0.27202123,
#  'Loss/total_loss': 0.9674101,
#  'learning_rate': 0.03333325}
# INFO:tensorflow:Step 1600 per-step time 0.760s
# I0205 13:21:52.051138 140002831592512 model_lib_v2.py:705] Step 1600 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.32036224,
#  'Loss/localization_loss': 0.26546106,
#  'Loss/regularization_loss': 0.26920602,
#  'Loss/total_loss': 0.85502934,
#  'learning_rate': 0.034666598}
# I0205 13:21:52.051488 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.32036224,
#  'Loss/localization_loss': 0.26546106,
#  'Loss/regularization_loss': 0.26920602,
#  'Loss/total_loss': 0.85502934,
#  'learning_rate': 0.034666598}
# INFO:tensorflow:Step 1700 per-step time 0.759s
# I0205 13:23:07.929162 140002831592512 model_lib_v2.py:705] Step 1700 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.28535563,
#  'Loss/localization_loss': 0.19318306,
#  'Loss/regularization_loss': 0.26655552,
#  'Loss/total_loss': 0.7450942,
#  'learning_rate': 0.03599995}
# I0205 13:23:07.929502 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.28535563,
#  'Loss/localization_loss': 0.19318306,
#  'Loss/regularization_loss': 0.26655552,
#  'Loss/total_loss': 0.7450942,
#  'learning_rate': 0.03599995}
# INFO:tensorflow:Step 1800 per-step time 0.759s
# I0205 13:24:23.851261 140002831592512 model_lib_v2.py:705] Step 1800 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.29694876,
#  'Loss/localization_loss': 0.17485318,
#  'Loss/regularization_loss': 0.2640682,
#  'Loss/total_loss': 0.7358701,
#  'learning_rate': 0.037333302}
# I0205 13:24:23.851601 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.29694876,
#  'Loss/localization_loss': 0.17485318,
#  'Loss/regularization_loss': 0.2640682,
#  'Loss/total_loss': 0.7358701,
#  'learning_rate': 0.037333302}
# INFO:tensorflow:Step 1900 per-step time 0.761s
# I0205 13:25:39.927328 140002831592512 model_lib_v2.py:705] Step 1900 per-step time 0.761s
# INFO:tensorflow:{'Loss/classification_loss': 0.321264,
#  'Loss/localization_loss': 0.17328763,
#  'Loss/regularization_loss': 0.26135656,
#  'Loss/total_loss': 0.7559082,
#  'learning_rate': 0.03866665}
# I0205 13:25:39.927679 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.321264,
#  'Loss/localization_loss': 0.17328763,
#  'Loss/regularization_loss': 0.26135656,
#  'Loss/total_loss': 0.7559082,
#  'learning_rate': 0.03866665}
# INFO:tensorflow:Step 2000 per-step time 0.758s
# I0205 13:26:55.756520 140002831592512 model_lib_v2.py:705] Step 2000 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.41833127,
#  'Loss/localization_loss': 0.17845432,
#  'Loss/regularization_loss': 0.25943324,
#  'Loss/total_loss': 0.8562188,
#  'learning_rate': 0.04}
# I0205 13:26:55.756853 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.41833127,
#  'Loss/localization_loss': 0.17845432,
#  'Loss/regularization_loss': 0.25943324,
#  'Loss/total_loss': 0.8562188,
#  'learning_rate': 0.04}
# INFO:tensorflow:Step 2100 per-step time 0.800s
# I0205 13:28:15.737239 140002831592512 model_lib_v2.py:705] Step 2100 per-step time 0.800s
# INFO:tensorflow:{'Loss/classification_loss': 0.32583603,
#  'Loss/localization_loss': 0.17983136,
#  'Loss/regularization_loss': 0.2569263,
#  'Loss/total_loss': 0.7625937,
#  'learning_rate': 0.039999895}
# I0205 13:28:15.737636 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.32583603,
#  'Loss/localization_loss': 0.17983136,
#  'Loss/regularization_loss': 0.2569263,
#  'Loss/total_loss': 0.7625937,
#  'learning_rate': 0.039999895}
# INFO:tensorflow:Step 2200 per-step time 0.759s
# I0205 13:29:31.653833 140002831592512 model_lib_v2.py:705] Step 2200 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.36505726,
#  'Loss/localization_loss': 0.14473255,
#  'Loss/regularization_loss': 0.25461182,
#  'Loss/total_loss': 0.7644017,
#  'learning_rate': 0.03999959}
# I0205 13:29:31.654196 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.36505726,
#  'Loss/localization_loss': 0.14473255,
#  'Loss/regularization_loss': 0.25461182,
#  'Loss/total_loss': 0.7644017,
#  'learning_rate': 0.03999959}
# INFO:tensorflow:Step 2300 per-step time 0.760s
# I0205 13:30:47.623195 140002831592512 model_lib_v2.py:705] Step 2300 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.27265924,
#  'Loss/localization_loss': 0.10236764,
#  'Loss/regularization_loss': 0.2530872,
#  'Loss/total_loss': 0.6281141,
#  'learning_rate': 0.039999075}
# I0205 13:30:47.623521 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.27265924,
#  'Loss/localization_loss': 0.10236764,
#  'Loss/regularization_loss': 0.2530872,
#  'Loss/total_loss': 0.6281141,
#  'learning_rate': 0.039999075}
# INFO:tensorflow:Step 2400 per-step time 0.760s
# I0205 13:32:03.652346 140002831592512 model_lib_v2.py:705] Step 2400 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.2583793,
#  'Loss/localization_loss': 0.17064002,
#  'Loss/regularization_loss': 0.25169623,
#  'Loss/total_loss': 0.68071556,
#  'learning_rate': 0.039998353}
# I0205 13:32:03.652681 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.2583793,
#  'Loss/localization_loss': 0.17064002,
#  'Loss/regularization_loss': 0.25169623,
#  'Loss/total_loss': 0.68071556,
#  'learning_rate': 0.039998353}
# INFO:tensorflow:Step 2500 per-step time 0.758s
# I0205 13:33:19.444923 140002831592512 model_lib_v2.py:705] Step 2500 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.33021194,
#  'Loss/localization_loss': 0.19732717,
#  'Loss/regularization_loss': 0.24915664,
#  'Loss/total_loss': 0.7766958,
#  'learning_rate': 0.03999743}
# I0205 13:33:19.445313 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.33021194,
#  'Loss/localization_loss': 0.19732717,
#  'Loss/regularization_loss': 0.24915664,
#  'Loss/total_loss': 0.7766958,
#  'learning_rate': 0.03999743}
# INFO:tensorflow:Step 2600 per-step time 0.759s
# I0205 13:34:35.301170 140002831592512 model_lib_v2.py:705] Step 2600 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.34565496,
#  'Loss/localization_loss': 0.24607979,
#  'Loss/regularization_loss': 0.24668694,
#  'Loss/total_loss': 0.8384217,
#  'learning_rate': 0.0399963}
# I0205 13:34:35.301503 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.34565496,
#  'Loss/localization_loss': 0.24607979,
#  'Loss/regularization_loss': 0.24668694,
#  'Loss/total_loss': 0.8384217,
#  'learning_rate': 0.0399963}
# INFO:tensorflow:Step 2700 per-step time 0.759s
# I0205 13:35:51.242438 140002831592512 model_lib_v2.py:705] Step 2700 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.6190225,
#  'Loss/localization_loss': 0.4237267,
#  'Loss/regularization_loss': 0.24410644,
#  'Loss/total_loss': 1.2868556,
#  'learning_rate': 0.039994963}
# I0205 13:35:51.242737 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.6190225,
#  'Loss/localization_loss': 0.4237267,
#  'Loss/regularization_loss': 0.24410644,
#  'Loss/total_loss': 1.2868556,
#  'learning_rate': 0.039994963}
# INFO:tensorflow:Step 2800 per-step time 0.758s
# I0205 13:37:07.080250 140002831592512 model_lib_v2.py:705] Step 2800 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.27940196,
#  'Loss/localization_loss': 0.1321227,
#  'Loss/regularization_loss': 0.24230689,
#  'Loss/total_loss': 0.65383154,
#  'learning_rate': 0.039993424}
# I0205 13:37:07.080585 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.27940196,
#  'Loss/localization_loss': 0.1321227,
#  'Loss/regularization_loss': 0.24230689,
#  'Loss/total_loss': 0.65383154,
#  'learning_rate': 0.039993424}
# INFO:tensorflow:Step 2900 per-step time 0.759s
# I0205 13:38:22.988726 140002831592512 model_lib_v2.py:705] Step 2900 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.3014959,
#  'Loss/localization_loss': 0.17372394,
#  'Loss/regularization_loss': 0.2397338,
#  'Loss/total_loss': 0.71495366,
#  'learning_rate': 0.039991677}
# I0205 13:38:22.989095 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.3014959,
#  'Loss/localization_loss': 0.17372394,
#  'Loss/regularization_loss': 0.2397338,
#  'Loss/total_loss': 0.71495366,
#  'learning_rate': 0.039991677}
# INFO:tensorflow:Step 3000 per-step time 0.759s
# I0205 13:39:38.866572 140002831592512 model_lib_v2.py:705] Step 3000 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.45610085,
#  'Loss/localization_loss': 0.20207892,
#  'Loss/regularization_loss': 0.2373825,
#  'Loss/total_loss': 0.8955623,
#  'learning_rate': 0.039989725}
# I0205 13:39:38.866908 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.45610085,
#  'Loss/localization_loss': 0.20207892,
#  'Loss/regularization_loss': 0.2373825,
#  'Loss/total_loss': 0.8955623,
#  'learning_rate': 0.039989725}
# INFO:tensorflow:Step 3100 per-step time 0.798s
# I0205 13:40:58.632062 140002831592512 model_lib_v2.py:705] Step 3100 per-step time 0.798s
# INFO:tensorflow:{'Loss/classification_loss': 0.34663042,
#  'Loss/localization_loss': 0.2918696,
#  'Loss/regularization_loss': 0.2350138,
#  'Loss/total_loss': 0.8735138,
#  'learning_rate': 0.039987564}
# I0205 13:40:58.632493 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.34663042,
#  'Loss/localization_loss': 0.2918696,
#  'Loss/regularization_loss': 0.2350138,
#  'Loss/total_loss': 0.8735138,
#  'learning_rate': 0.039987564}
# INFO:tensorflow:Step 3200 per-step time 0.760s
# I0205 13:42:14.588243 140002831592512 model_lib_v2.py:705] Step 3200 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.30801716,
#  'Loss/localization_loss': 0.19065857,
#  'Loss/regularization_loss': 0.23332652,
#  'Loss/total_loss': 0.73200226,
#  'learning_rate': 0.039985202}
# I0205 13:42:14.588567 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.30801716,
#  'Loss/localization_loss': 0.19065857,
#  'Loss/regularization_loss': 0.23332652,
#  'Loss/total_loss': 0.73200226,
#  'learning_rate': 0.039985202}
# INFO:tensorflow:Step 3300 per-step time 0.759s
# I0205 13:43:30.509241 140002831592512 model_lib_v2.py:705] Step 3300 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.3656952,
#  'Loss/localization_loss': 0.2404879,
#  'Loss/regularization_loss': 0.23205963,
#  'Loss/total_loss': 0.83824277,
#  'learning_rate': 0.03998263}
# I0205 13:43:30.509560 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.3656952,
#  'Loss/localization_loss': 0.2404879,
#  'Loss/regularization_loss': 0.23205963,
#  'Loss/total_loss': 0.83824277,
#  'learning_rate': 0.03998263}
# INFO:tensorflow:Step 3400 per-step time 0.759s
# I0205 13:44:46.426431 140002831592512 model_lib_v2.py:705] Step 3400 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.33841524,
#  'Loss/localization_loss': 0.18791848,
#  'Loss/regularization_loss': 0.22993454,
#  'Loss/total_loss': 0.75626826,
#  'learning_rate': 0.03997986}
# I0205 13:44:46.426756 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.33841524,
#  'Loss/localization_loss': 0.18791848,
#  'Loss/regularization_loss': 0.22993454,
#  'Loss/total_loss': 0.75626826,
#  'learning_rate': 0.03997986}
# INFO:tensorflow:Step 3500 per-step time 0.760s
# I0205 13:46:02.439388 140002831592512 model_lib_v2.py:705] Step 3500 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.28116578,
#  'Loss/localization_loss': 0.114331655,
#  'Loss/regularization_loss': 0.2288033,
#  'Loss/total_loss': 0.6243007,
#  'learning_rate': 0.039976884}
# I0205 13:46:02.439697 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.28116578,
#  'Loss/localization_loss': 0.114331655,
#  'Loss/regularization_loss': 0.2288033,
#  'Loss/total_loss': 0.6243007,
#  'learning_rate': 0.039976884}
# INFO:tensorflow:Step 3600 per-step time 0.760s
# I0205 13:47:18.391642 140002831592512 model_lib_v2.py:705] Step 3600 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.18815298,
#  'Loss/localization_loss': 0.07896736,
#  'Loss/regularization_loss': 0.22734988,
#  'Loss/total_loss': 0.49447024,
#  'learning_rate': 0.0399737}
# I0205 13:47:18.391999 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.18815298,
#  'Loss/localization_loss': 0.07896736,
#  'Loss/regularization_loss': 0.22734988,
#  'Loss/total_loss': 0.49447024,
#  'learning_rate': 0.0399737}
# INFO:tensorflow:Step 3700 per-step time 0.760s
# I0205 13:48:34.362726 140002831592512 model_lib_v2.py:705] Step 3700 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.22264385,
#  'Loss/localization_loss': 0.081328474,
#  'Loss/regularization_loss': 0.22578901,
#  'Loss/total_loss': 0.5297613,
#  'learning_rate': 0.039970305}
# I0205 13:48:34.363075 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.22264385,
#  'Loss/localization_loss': 0.081328474,
#  'Loss/regularization_loss': 0.22578901,
#  'Loss/total_loss': 0.5297613,
#  'learning_rate': 0.039970305}
# INFO:tensorflow:Step 3800 per-step time 0.759s
# I0205 13:49:50.286558 140002831592512 model_lib_v2.py:705] Step 3800 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.25323403,
#  'Loss/localization_loss': 0.16991603,
#  'Loss/regularization_loss': 0.22461136,
#  'Loss/total_loss': 0.6477614,
#  'learning_rate': 0.03996671}
# I0205 13:49:50.286900 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.25323403,
#  'Loss/localization_loss': 0.16991603,
#  'Loss/regularization_loss': 0.22461136,
#  'Loss/total_loss': 0.6477614,
#  'learning_rate': 0.03996671}
# INFO:tensorflow:Step 3900 per-step time 0.760s
# I0205 13:51:06.281648 140002831592512 model_lib_v2.py:705] Step 3900 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.30197668,
#  'Loss/localization_loss': 0.14115143,
#  'Loss/regularization_loss': 0.22375737,
#  'Loss/total_loss': 0.6668855,
#  'learning_rate': 0.03996291}
# I0205 13:51:06.282008 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.30197668,
#  'Loss/localization_loss': 0.14115143,
#  'Loss/regularization_loss': 0.22375737,
#  'Loss/total_loss': 0.6668855,
#  'learning_rate': 0.03996291}
# INFO:tensorflow:Step 4000 per-step time 0.759s
# I0205 13:52:22.215955 140002831592512 model_lib_v2.py:705] Step 4000 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.2696253,
#  'Loss/localization_loss': 0.16006592,
#  'Loss/regularization_loss': 0.22274025,
#  'Loss/total_loss': 0.6524315,
#  'learning_rate': 0.039958905}
# I0205 13:52:22.216269 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.2696253,
#  'Loss/localization_loss': 0.16006592,
#  'Loss/regularization_loss': 0.22274025,
#  'Loss/total_loss': 0.6524315,
#  'learning_rate': 0.039958905}
# INFO:tensorflow:Step 4100 per-step time 0.796s
# I0205 13:53:41.860591 140002831592512 model_lib_v2.py:705] Step 4100 per-step time 0.796s
# INFO:tensorflow:{'Loss/classification_loss': 0.27084598,
#  'Loss/localization_loss': 0.21196769,
#  'Loss/regularization_loss': 0.22120994,
#  'Loss/total_loss': 0.7040236,
#  'learning_rate': 0.039954696}
# I0205 13:53:41.860928 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.27084598,
#  'Loss/localization_loss': 0.21196769,
#  'Loss/regularization_loss': 0.22120994,
#  'Loss/total_loss': 0.7040236,
#  'learning_rate': 0.039954696}
# INFO:tensorflow:Step 4200 per-step time 0.759s
# I0205 13:54:57.734944 140002831592512 model_lib_v2.py:705] Step 4200 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.25371125,
#  'Loss/localization_loss': 0.0924707,
#  'Loss/regularization_loss': 0.2201118,
#  'Loss/total_loss': 0.5662938,
#  'learning_rate': 0.03995028}
# I0205 13:54:57.735272 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.25371125,
#  'Loss/localization_loss': 0.0924707,
#  'Loss/regularization_loss': 0.2201118,
#  'Loss/total_loss': 0.5662938,
#  'learning_rate': 0.03995028}
# INFO:tensorflow:Step 4300 per-step time 0.760s
# I0205 13:56:13.738015 140002831592512 model_lib_v2.py:705] Step 4300 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.22727212,
#  'Loss/localization_loss': 0.17999107,
#  'Loss/regularization_loss': 0.21934386,
#  'Loss/total_loss': 0.62660706,
#  'learning_rate': 0.039945662}
# I0205 13:56:13.738361 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.22727212,
#  'Loss/localization_loss': 0.17999107,
#  'Loss/regularization_loss': 0.21934386,
#  'Loss/total_loss': 0.62660706,
#  'learning_rate': 0.039945662}
# INFO:tensorflow:Step 4400 per-step time 0.759s
# I0205 13:57:29.638293 140002831592512 model_lib_v2.py:705] Step 4400 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.20256633,
#  'Loss/localization_loss': 0.16191642,
#  'Loss/regularization_loss': 0.21853971,
#  'Loss/total_loss': 0.5830225,
#  'learning_rate': 0.039940834}
# I0205 13:57:29.638616 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.20256633,
#  'Loss/localization_loss': 0.16191642,
#  'Loss/regularization_loss': 0.21853971,
#  'Loss/total_loss': 0.5830225,
#  'learning_rate': 0.039940834}
# INFO:tensorflow:Step 4500 per-step time 0.760s
# I0205 13:58:45.591250 140002831592512 model_lib_v2.py:705] Step 4500 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.3114159,
#  'Loss/localization_loss': 0.16525398,
#  'Loss/regularization_loss': 0.21772045,
#  'Loss/total_loss': 0.69439036,
#  'learning_rate': 0.039935805}
# I0205 13:58:45.591565 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.3114159,
#  'Loss/localization_loss': 0.16525398,
#  'Loss/regularization_loss': 0.21772045,
#  'Loss/total_loss': 0.69439036,
#  'learning_rate': 0.039935805}
# INFO:tensorflow:Step 4600 per-step time 0.760s
# I0205 14:00:01.549566 140002831592512 model_lib_v2.py:705] Step 4600 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.7085659,
#  'Loss/localization_loss': 0.5033693,
#  'Loss/regularization_loss': 0.21696796,
#  'Loss/total_loss': 1.4289031,
#  'learning_rate': 0.03993057}
# I0205 14:00:01.549897 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.7085659,
#  'Loss/localization_loss': 0.5033693,
#  'Loss/regularization_loss': 0.21696796,
#  'Loss/total_loss': 1.4289031,
#  'learning_rate': 0.03993057}
# INFO:tensorflow:Step 4700 per-step time 0.760s
# I0205 14:01:17.512319 140002831592512 model_lib_v2.py:705] Step 4700 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.30247357,
#  'Loss/localization_loss': 0.15982601,
#  'Loss/regularization_loss': 0.2163634,
#  'Loss/total_loss': 0.678663,
#  'learning_rate': 0.039925132}
# I0205 14:01:17.512639 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.30247357,
#  'Loss/localization_loss': 0.15982601,
#  'Loss/regularization_loss': 0.2163634,
#  'Loss/total_loss': 0.678663,
#  'learning_rate': 0.039925132}
# INFO:tensorflow:Step 4800 per-step time 0.759s
# I0205 14:02:33.457792 140002831592512 model_lib_v2.py:705] Step 4800 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.20463023,
#  'Loss/localization_loss': 0.16516568,
#  'Loss/regularization_loss': 0.21532817,
#  'Loss/total_loss': 0.5851241,
#  'learning_rate': 0.039919484}
# I0205 14:02:33.458148 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.20463023,
#  'Loss/localization_loss': 0.16516568,
#  'Loss/regularization_loss': 0.21532817,
#  'Loss/total_loss': 0.5851241,
#  'learning_rate': 0.039919484}
# INFO:tensorflow:Step 4900 per-step time 0.760s
# I0205 14:03:49.462309 140002831592512 model_lib_v2.py:705] Step 4900 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.19666535,
#  'Loss/localization_loss': 0.1414738,
#  'Loss/regularization_loss': 0.21512474,
#  'Loss/total_loss': 0.5532639,
#  'learning_rate': 0.039913636}
# I0205 14:03:49.462623 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.19666535,
#  'Loss/localization_loss': 0.1414738,
#  'Loss/regularization_loss': 0.21512474,
#  'Loss/total_loss': 0.5532639,
#  'learning_rate': 0.039913636}
# INFO:tensorflow:Step 5000 per-step time 0.759s
# I0205 14:05:05.326639 140002831592512 model_lib_v2.py:705] Step 5000 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.21166523,
#  'Loss/localization_loss': 0.12889156,
#  'Loss/regularization_loss': 0.213675,
#  'Loss/total_loss': 0.5542318,
#  'learning_rate': 0.039907582}
# I0205 14:05:05.326991 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.21166523,
#  'Loss/localization_loss': 0.12889156,
#  'Loss/regularization_loss': 0.213675,
#  'Loss/total_loss': 0.5542318,
#  'learning_rate': 0.039907582}
# INFO:tensorflow:Step 5100 per-step time 0.804s
# I0205 14:06:25.685146 140002831592512 model_lib_v2.py:705] Step 5100 per-step time 0.804s
# INFO:tensorflow:{'Loss/classification_loss': 0.2372169,
#  'Loss/localization_loss': 0.11290448,
#  'Loss/regularization_loss': 0.21335849,
#  'Loss/total_loss': 0.5634799,
#  'learning_rate': 0.039901324}
# I0205 14:06:25.685487 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.2372169,
#  'Loss/localization_loss': 0.11290448,
#  'Loss/regularization_loss': 0.21335849,
#  'Loss/total_loss': 0.5634799,
#  'learning_rate': 0.039901324}
# INFO:tensorflow:Step 5200 per-step time 0.760s
# I0205 14:07:41.724628 140002831592512 model_lib_v2.py:705] Step 5200 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.13959056,
#  'Loss/localization_loss': 0.08902302,
#  'Loss/regularization_loss': 0.21216379,
#  'Loss/total_loss': 0.44077736,
#  'learning_rate': 0.03989486}
# I0205 14:07:41.724947 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.13959056,
#  'Loss/localization_loss': 0.08902302,
#  'Loss/regularization_loss': 0.21216379,
#  'Loss/total_loss': 0.44077736,
#  'learning_rate': 0.03989486}
# INFO:tensorflow:Step 5300 per-step time 0.759s
# I0205 14:08:57.634974 140002831592512 model_lib_v2.py:705] Step 5300 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.17946884,
#  'Loss/localization_loss': 0.102690555,
#  'Loss/regularization_loss': 0.21116194,
#  'Loss/total_loss': 0.49332133,
#  'learning_rate': 0.039888192}
# I0205 14:08:57.635280 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.17946884,
#  'Loss/localization_loss': 0.102690555,
#  'Loss/regularization_loss': 0.21116194,
#  'Loss/total_loss': 0.49332133,
#  'learning_rate': 0.039888192}
# INFO:tensorflow:Step 5400 per-step time 0.760s
# I0205 14:10:13.631364 140002831592512 model_lib_v2.py:705] Step 5400 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.18300456,
#  'Loss/localization_loss': 0.08187245,
#  'Loss/regularization_loss': 0.21143466,
#  'Loss/total_loss': 0.47631168,
#  'learning_rate': 0.03988132}
# I0205 14:10:13.631695 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.18300456,
#  'Loss/localization_loss': 0.08187245,
#  'Loss/regularization_loss': 0.21143466,
#  'Loss/total_loss': 0.47631168,
#  'learning_rate': 0.03988132}
# INFO:tensorflow:Step 5500 per-step time 0.758s
# I0205 14:11:29.406893 140002831592512 model_lib_v2.py:705] Step 5500 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.24047089,
#  'Loss/localization_loss': 0.078396656,
#  'Loss/regularization_loss': 0.211496,
#  'Loss/total_loss': 0.53036356,
#  'learning_rate': 0.039874244}
# I0205 14:11:29.407249 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.24047089,
#  'Loss/localization_loss': 0.078396656,
#  'Loss/regularization_loss': 0.211496,
#  'Loss/total_loss': 0.53036356,
#  'learning_rate': 0.039874244}
# INFO:tensorflow:Step 5600 per-step time 0.759s
# I0205 14:12:45.265465 140002831592512 model_lib_v2.py:705] Step 5600 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.33448452,
#  'Loss/localization_loss': 0.12996827,
#  'Loss/regularization_loss': 0.21136169,
#  'Loss/total_loss': 0.6758145,
#  'learning_rate': 0.03986696}
# I0205 14:12:45.265769 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.33448452,
#  'Loss/localization_loss': 0.12996827,
#  'Loss/regularization_loss': 0.21136169,
#  'Loss/total_loss': 0.6758145,
#  'learning_rate': 0.03986696}
# INFO:tensorflow:Step 5700 per-step time 0.760s
# I0205 14:14:01.244146 140002831592512 model_lib_v2.py:705] Step 5700 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.17906497,
#  'Loss/localization_loss': 0.09027084,
#  'Loss/regularization_loss': 0.2110102,
#  'Loss/total_loss': 0.48034602,
#  'learning_rate': 0.039859477}
# I0205 14:14:01.244456 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.17906497,
#  'Loss/localization_loss': 0.09027084,
#  'Loss/regularization_loss': 0.2110102,
#  'Loss/total_loss': 0.48034602,
#  'learning_rate': 0.039859477}
# INFO:tensorflow:Step 5800 per-step time 0.760s
# I0205 14:15:17.208746 140002831592512 model_lib_v2.py:705] Step 5800 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.1363637,
#  'Loss/localization_loss': 0.12224971,
#  'Loss/regularization_loss': 0.2100035,
#  'Loss/total_loss': 0.4686169,
#  'learning_rate': 0.03985179}
# I0205 14:15:17.209072 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.1363637,
#  'Loss/localization_loss': 0.12224971,
#  'Loss/regularization_loss': 0.2100035,
#  'Loss/total_loss': 0.4686169,
#  'learning_rate': 0.03985179}
# INFO:tensorflow:Step 5900 per-step time 0.760s
# I0205 14:16:33.236582 140002831592512 model_lib_v2.py:705] Step 5900 per-step time 0.760s
# INFO:tensorflow:{'Loss/classification_loss': 0.22910601,
#  'Loss/localization_loss': 0.12804148,
#  'Loss/regularization_loss': 0.20918415,
#  'Loss/total_loss': 0.5663316,
#  'learning_rate': 0.0398439}
# I0205 14:16:33.236902 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.22910601,
#  'Loss/localization_loss': 0.12804148,
#  'Loss/regularization_loss': 0.20918415,
#  'Loss/total_loss': 0.5663316,
#  'learning_rate': 0.0398439}
# INFO:tensorflow:Step 6000 per-step time 0.759s
# I0205 14:17:49.106504 140002831592512 model_lib_v2.py:705] Step 6000 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.19705933,
#  'Loss/localization_loss': 0.12850289,
#  'Loss/regularization_loss': 0.20913903,
#  'Loss/total_loss': 0.5347013,
#  'learning_rate': 0.0398358}
# I0205 14:17:49.106814 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.19705933,
#  'Loss/localization_loss': 0.12850289,
#  'Loss/regularization_loss': 0.20913903,
#  'Loss/total_loss': 0.5347013,
#  'learning_rate': 0.0398358}
# INFO:tensorflow:Step 6100 per-step time 0.797s
# I0205 14:19:08.825427 140002831592512 model_lib_v2.py:705] Step 6100 per-step time 0.797s
# INFO:tensorflow:{'Loss/classification_loss': 0.18984012,
#  'Loss/localization_loss': 0.037177175,
#  'Loss/regularization_loss': 0.20926642,
#  'Loss/total_loss': 0.4362837,
#  'learning_rate': 0.0398275}
# I0205 14:19:08.825744 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.18984012,
#  'Loss/localization_loss': 0.037177175,
#  'Loss/regularization_loss': 0.20926642,
#  'Loss/total_loss': 0.4362837,
#  'learning_rate': 0.0398275}
# INFO:tensorflow:Step 6200 per-step time 0.759s
# I0205 14:20:24.756746 140002831592512 model_lib_v2.py:705] Step 6200 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.24901024,
#  'Loss/localization_loss': 0.17928989,
#  'Loss/regularization_loss': 0.20933895,
#  'Loss/total_loss': 0.6376391,
#  'learning_rate': 0.039818995}
# I0205 14:20:24.757081 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.24901024,
#  'Loss/localization_loss': 0.17928989,
#  'Loss/regularization_loss': 0.20933895,
#  'Loss/total_loss': 0.6376391,
#  'learning_rate': 0.039818995}
# INFO:tensorflow:Step 6300 per-step time 0.759s
# ...
#  'Loss/total_loss': 0.28843904,
#  'learning_rate': 0.029590093}
# I0205 20:31:39.647819 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.083753295,
#  'Loss/localization_loss': 0.033589628,
#  'Loss/regularization_loss': 0.17109612,
#  'Loss/total_loss': 0.28843904,
#  'learning_rate': 0.029590093}
# INFO:tensorflow:Step 35500 per-step time 0.757s
# I0205 20:32:55.381914 140002831592512 model_lib_v2.py:705] Step 35500 per-step time 0.757s
# INFO:tensorflow:{'Loss/classification_loss': 0.09210563,
#  'Loss/localization_loss': 0.03304807,
#  'Loss/regularization_loss': 0.1694468,
#  'Loss/total_loss': 0.2946005,
#  'learning_rate': 0.029533781}
# I0205 20:32:55.382240 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.09210563,
#  'Loss/localization_loss': 0.03304807,
#  'Loss/regularization_loss': 0.1694468,
#  'Loss/total_loss': 0.2946005,
#  'learning_rate': 0.029533781}
# INFO:tensorflow:Step 35600 per-step time 0.757s
# I0205 20:34:11.089825 140002831592512 model_lib_v2.py:705] Step 35600 per-step time 0.757s
# INFO:tensorflow:{'Loss/classification_loss': 0.07203811,
#  'Loss/localization_loss': 0.033589397,
#  'Loss/regularization_loss': 0.1683538,
#  'Loss/total_loss': 0.2739813,
#  'learning_rate': 0.02947737}
# I0205 20:34:11.090147 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.07203811,
#  'Loss/localization_loss': 0.033589397,
#  'Loss/regularization_loss': 0.1683538,
#  'Loss/total_loss': 0.2739813,
#  'learning_rate': 0.02947737}
# INFO:tensorflow:Step 35700 per-step time 0.758s
# I0205 20:35:26.920962 140002831592512 model_lib_v2.py:705] Step 35700 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.08647791,
#  'Loss/localization_loss': 0.016169585,
#  'Loss/regularization_loss': 0.1668325,
#  'Loss/total_loss': 0.26948,
#  'learning_rate': 0.029420866}
# I0205 20:35:26.921273 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.08647791,
#  'Loss/localization_loss': 0.016169585,
#  'Loss/regularization_loss': 0.1668325,
#  'Loss/total_loss': 0.26948,
#  'learning_rate': 0.029420866}
# INFO:tensorflow:Step 35800 per-step time 0.759s
# I0205 20:36:42.836758 140002831592512 model_lib_v2.py:705] Step 35800 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.17989889,
#  'Loss/localization_loss': 0.036653295,
#  'Loss/regularization_loss': 0.16657206,
#  'Loss/total_loss': 0.38312423,
#  'learning_rate': 0.029364262}
# I0205 20:36:42.837093 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.17989889,
#  'Loss/localization_loss': 0.036653295,
#  'Loss/regularization_loss': 0.16657206,
#  'Loss/total_loss': 0.38312423,
#  'learning_rate': 0.029364262}
# INFO:tensorflow:Step 35900 per-step time 0.758s
# I0205 20:37:58.680983 140002831592512 model_lib_v2.py:705] Step 35900 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.11803725,
#  'Loss/localization_loss': 0.038514692,
#  'Loss/regularization_loss': 0.1677982,
#  'Loss/total_loss': 0.32435015,
#  'learning_rate': 0.029307561}
# I0205 20:37:58.681298 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.11803725,
#  'Loss/localization_loss': 0.038514692,
#  'Loss/regularization_loss': 0.1677982,
#  'Loss/total_loss': 0.32435015,
#  'learning_rate': 0.029307561}
# INFO:tensorflow:Step 36000 per-step time 0.758s
# I0205 20:39:14.494166 140002831592512 model_lib_v2.py:705] Step 36000 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.08132146,
#  'Loss/localization_loss': 0.01887734,
#  'Loss/regularization_loss': 0.16820976,
#  'Loss/total_loss': 0.26840857,
#  'learning_rate': 0.029250763}
# I0205 20:39:14.494495 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.08132146,
#  'Loss/localization_loss': 0.01887734,
#  'Loss/regularization_loss': 0.16820976,
#  'Loss/total_loss': 0.26840857,
#  'learning_rate': 0.029250763}
# INFO:tensorflow:Step 36100 per-step time 0.796s
# I0205 20:40:34.057343 140002831592512 model_lib_v2.py:705] Step 36100 per-step time 0.796s
# INFO:tensorflow:{'Loss/classification_loss': 0.0975153,
#  'Loss/localization_loss': 0.06788516,
#  'Loss/regularization_loss': 0.16927232,
#  'Loss/total_loss': 0.33467278,
#  'learning_rate': 0.029193873}
# I0205 20:40:34.057667 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0975153,
#  'Loss/localization_loss': 0.06788516,
#  'Loss/regularization_loss': 0.16927232,
#  'Loss/total_loss': 0.33467278,
#  'learning_rate': 0.029193873}
# INFO:tensorflow:Step 36200 per-step time 0.759s
# I0205 20:41:49.928069 140002831592512 model_lib_v2.py:705] Step 36200 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.11353726,
#  'Loss/localization_loss': 0.028280197,
#  'Loss/regularization_loss': 0.17078127,
#  'Loss/total_loss': 0.3125987,
#  'learning_rate': 0.029136889}
# I0205 20:41:49.928410 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.11353726,
#  'Loss/localization_loss': 0.028280197,
#  'Loss/regularization_loss': 0.17078127,
#  'Loss/total_loss': 0.3125987,
#  'learning_rate': 0.029136889}
# INFO:tensorflow:Step 36300 per-step time 0.758s
# I0205 20:43:05.699495 140002831592512 model_lib_v2.py:705] Step 36300 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.13916071,
#  'Loss/localization_loss': 0.033364996,
#  'Loss/regularization_loss': 0.16963756,
#  'Loss/total_loss': 0.34216326,
#  'learning_rate': 0.029079808}
# I0205 20:43:05.699852 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.13916071,
#  'Loss/localization_loss': 0.033364996,
#  'Loss/regularization_loss': 0.16963756,
#  'Loss/total_loss': 0.34216326,
#  'learning_rate': 0.029079808}
# INFO:tensorflow:Step 36400 per-step time 0.758s
# I0205 20:44:21.465622 140002831592512 model_lib_v2.py:705] Step 36400 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.1178359,
#  'Loss/localization_loss': 0.070242055,
#  'Loss/regularization_loss': 0.1721725,
#  'Loss/total_loss': 0.36025047,
#  'learning_rate': 0.029022636}
# I0205 20:44:21.465947 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.1178359,
#  'Loss/localization_loss': 0.070242055,
#  'Loss/regularization_loss': 0.1721725,
#  'Loss/total_loss': 0.36025047,
#  'learning_rate': 0.029022636}
# INFO:tensorflow:Step 36500 per-step time 0.758s
# I0205 20:45:37.271936 140002831592512 model_lib_v2.py:705] Step 36500 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.086549565,
#  'Loss/localization_loss': 0.04613032,
#  'Loss/regularization_loss': 0.17265274,
#  'Loss/total_loss': 0.3053326,
#  'learning_rate': 0.02896537}
# I0205 20:45:37.272254 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.086549565,
#  'Loss/localization_loss': 0.04613032,
#  'Loss/regularization_loss': 0.17265274,
#  'Loss/total_loss': 0.3053326,
#  'learning_rate': 0.02896537}
# INFO:tensorflow:Step 36600 per-step time 0.758s
# I0205 20:46:53.091936 140002831592512 model_lib_v2.py:705] Step 36600 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.19960503,
#  'Loss/localization_loss': 0.13992065,
#  'Loss/regularization_loss': 0.17385915,
#  'Loss/total_loss': 0.5133848,
#  'learning_rate': 0.028908014}
# I0205 20:46:53.092273 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.19960503,
#  'Loss/localization_loss': 0.13992065,
#  'Loss/regularization_loss': 0.17385915,
#  'Loss/total_loss': 0.5133848,
#  'learning_rate': 0.028908014}
# INFO:tensorflow:Step 36700 per-step time 0.758s
# I0205 20:48:08.883916 140002831592512 model_lib_v2.py:705] Step 36700 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.11456971,
#  'Loss/localization_loss': 0.030162489,
#  'Loss/regularization_loss': 0.17713122,
#  'Loss/total_loss': 0.3218634,
#  'learning_rate': 0.028850565}
# I0205 20:48:08.884238 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.11456971,
#  'Loss/localization_loss': 0.030162489,
#  'Loss/regularization_loss': 0.17713122,
#  'Loss/total_loss': 0.3218634,
#  'learning_rate': 0.028850565}
# INFO:tensorflow:Step 36800 per-step time 0.758s
# I0205 20:49:24.709008 140002831592512 model_lib_v2.py:705] Step 36800 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.10638257,
#  'Loss/localization_loss': 0.024170844,
#  'Loss/regularization_loss': 0.1778104,
#  'Loss/total_loss': 0.3083638,
#  'learning_rate': 0.028793024}
# I0205 20:49:24.709324 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.10638257,
#  'Loss/localization_loss': 0.024170844,
#  'Loss/regularization_loss': 0.1778104,
#  'Loss/total_loss': 0.3083638,
#  'learning_rate': 0.028793024}
# INFO:tensorflow:Step 36900 per-step time 0.758s
# I0205 20:50:40.458941 140002831592512 model_lib_v2.py:705] Step 36900 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.060382128,
#  'Loss/localization_loss': 0.031543564,
#  'Loss/regularization_loss': 0.1779421,
#  'Loss/total_loss': 0.26986778,
#  'learning_rate': 0.028735394}
# I0205 20:50:40.459253 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.060382128,
#  'Loss/localization_loss': 0.031543564,
#  'Loss/regularization_loss': 0.1779421,
#  'Loss/total_loss': 0.26986778,
#  'learning_rate': 0.028735394}
# INFO:tensorflow:Step 37000 per-step time 0.758s
# I0205 20:51:56.214856 140002831592512 model_lib_v2.py:705] Step 37000 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.06237506,
#  'Loss/localization_loss': 0.02235778,
#  'Loss/regularization_loss': 0.17638056,
#  'Loss/total_loss': 0.2611134,
#  'learning_rate': 0.028677676}
# I0205 20:51:56.215216 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.06237506,
#  'Loss/localization_loss': 0.02235778,
#  'Loss/regularization_loss': 0.17638056,
#  'Loss/total_loss': 0.2611134,
#  'learning_rate': 0.028677676}
# INFO:tensorflow:Step 37100 per-step time 0.799s
# I0205 20:53:16.108266 140002831592512 model_lib_v2.py:705] Step 37100 per-step time 0.799s
# INFO:tensorflow:{'Loss/classification_loss': 0.07727316,
#  'Loss/localization_loss': 0.022642858,
#  'Loss/regularization_loss': 0.17445175,
#  'Loss/total_loss': 0.27436778,
#  'learning_rate': 0.028619863}
# I0205 20:53:16.108613 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.07727316,
#  'Loss/localization_loss': 0.022642858,
#  'Loss/regularization_loss': 0.17445175,
#  'Loss/total_loss': 0.27436778,
#  'learning_rate': 0.028619863}
# INFO:tensorflow:Step 37200 per-step time 0.759s
# I0205 20:54:32.020775 140002831592512 model_lib_v2.py:705] Step 37200 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.04905587,
#  'Loss/localization_loss': 0.024175908,
#  'Loss/regularization_loss': 0.17318827,
#  'Loss/total_loss': 0.24642006,
#  'learning_rate': 0.028561968}
# I0205 20:54:32.021109 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.04905587,
#  'Loss/localization_loss': 0.024175908,
#  'Loss/regularization_loss': 0.17318827,
#  'Loss/total_loss': 0.24642006,
#  'learning_rate': 0.028561968}
# INFO:tensorflow:Step 37300 per-step time 0.758s
# I0205 20:55:47.774028 140002831592512 model_lib_v2.py:705] Step 37300 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.09217199,
#  'Loss/localization_loss': 0.027759047,
#  'Loss/regularization_loss': 0.17121726,
#  'Loss/total_loss': 0.2911483,
#  'learning_rate': 0.02850398}
# I0205 20:55:47.774372 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.09217199,
#  'Loss/localization_loss': 0.027759047,
#  'Loss/regularization_loss': 0.17121726,
#  'Loss/total_loss': 0.2911483,
#  'learning_rate': 0.02850398}
# INFO:tensorflow:Step 37400 per-step time 0.759s
# I0205 20:57:03.641472 140002831592512 model_lib_v2.py:705] Step 37400 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.06546966,
#  'Loss/localization_loss': 0.01073601,
#  'Loss/regularization_loss': 0.16946582,
#  'Loss/total_loss': 0.2456715,
#  'learning_rate': 0.028445909}
# I0205 20:57:03.641783 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.06546966,
#  'Loss/localization_loss': 0.01073601,
#  'Loss/regularization_loss': 0.16946582,
#  'Loss/total_loss': 0.2456715,
#  'learning_rate': 0.028445909}
# INFO:tensorflow:Step 37500 per-step time 0.759s
# I0205 20:58:19.531018 140002831592512 model_lib_v2.py:705] Step 37500 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.0655001,
#  'Loss/localization_loss': 0.030899275,
#  'Loss/regularization_loss': 0.16770725,
#  'Loss/total_loss': 0.26410663,
#  'learning_rate': 0.028387748}
# I0205 20:58:19.531348 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.0655001,
#  'Loss/localization_loss': 0.030899275,
#  'Loss/regularization_loss': 0.16770725,
#  'Loss/total_loss': 0.26410663,
#  'learning_rate': 0.028387748}
# INFO:tensorflow:Step 37600 per-step time 0.758s
# I0205 20:59:35.291444 140002831592512 model_lib_v2.py:705] Step 37600 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.08399515,
#  'Loss/localization_loss': 0.015214893,
#  'Loss/regularization_loss': 0.1658974,
#  'Loss/total_loss': 0.26510745,
#  'learning_rate': 0.0283295}
# I0205 20:59:35.291772 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.08399515,
#  'Loss/localization_loss': 0.015214893,
#  'Loss/regularization_loss': 0.1658974,
#  'Loss/total_loss': 0.26510745,
#  'learning_rate': 0.0283295}
# INFO:tensorflow:Step 37700 per-step time 0.759s
# I0205 21:00:51.215283 140002831592512 model_lib_v2.py:705] Step 37700 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.11480553,
#  'Loss/localization_loss': 0.02413969,
#  'Loss/regularization_loss': 0.16434279,
#  'Loss/total_loss': 0.303288,
#  'learning_rate': 0.028271168}
# I0205 21:00:51.215657 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.11480553,
#  'Loss/localization_loss': 0.02413969,
#  'Loss/regularization_loss': 0.16434279,
#  'Loss/total_loss': 0.303288,
#  'learning_rate': 0.028271168}
# INFO:tensorflow:Step 37800 per-step time 0.758s
# I0205 21:02:06.984349 140002831592512 model_lib_v2.py:705] Step 37800 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.048310414,
#  'Loss/localization_loss': 0.024354614,
#  'Loss/regularization_loss': 0.16292809,
#  'Loss/total_loss': 0.23559311,
#  'learning_rate': 0.028212752}
# I0205 21:02:06.984671 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.048310414,
#  'Loss/localization_loss': 0.024354614,
#  'Loss/regularization_loss': 0.16292809,
#  'Loss/total_loss': 0.23559311,
#  'learning_rate': 0.028212752}
# INFO:tensorflow:Step 37900 per-step time 0.759s
# I0205 21:03:22.914150 140002831592512 model_lib_v2.py:705] Step 37900 per-step time 0.759s
# INFO:tensorflow:{'Loss/classification_loss': 0.11461169,
#  'Loss/localization_loss': 0.029171497,
#  'Loss/regularization_loss': 0.16188912,
#  'Loss/total_loss': 0.3056723,
#  'learning_rate': 0.02815425}
# I0205 21:03:22.914467 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.11461169,
#  'Loss/localization_loss': 0.029171497,
#  'Loss/regularization_loss': 0.16188912,
#  'Loss/total_loss': 0.3056723,
#  'learning_rate': 0.02815425}
# INFO:tensorflow:Step 38000 per-step time 0.758s
# I0205 21:04:38.752729 140002831592512 model_lib_v2.py:705] Step 38000 per-step time 0.758s
# INFO:tensorflow:{'Loss/classification_loss': 0.15200992,
#  'Loss/localization_loss': 0.044386063,
#  'Loss/regularization_loss': 0.16327451,
#  'Loss/total_loss': 0.3596705,
#  'learning_rate': 0.028095666}
# I0205 21:04:38.753460 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.15200992,
#  'Loss/localization_loss': 0.044386063,
#  'Loss/regularization_loss': 0.16327451,
#  'Loss/total_loss': 0.3596705,
#  'learning_rate': 0.028095666}
# INFO:tensorflow:Step 38100 per-step time 0.806s
# I0205 21:05:59.369577 140002831592512 model_lib_v2.py:705] Step 38100 per-step time 0.806s
# INFO:tensorflow:{'Loss/classification_loss': 0.048829082,
#  'Loss/localization_loss': 0.046563797,
#  'Loss/regularization_loss': 0.16255288,
#  'Loss/total_loss': 0.25794578,
#  'learning_rate': 0.028036999}
# I0205 21:05:59.369928 140002831592512 model_lib_v2.py:708] {'Loss/classification_loss': 0.048829082,
#  'Loss/localization_loss': 0.046563797,
#  'Loss/regularization_loss': 0.16255288,
#  'Loss/total_loss': 0.25794578,
#  'learning_rate': 0.028036999}

# %% [markdown]
# ## Export Model

# %%
cd /content/drive/MyDrive/tf_workspace/training_demo
# Out:
# /content/drive/MyDrive/tf_workspace/training_demo

# %%
# !python pascal_xml_to_tfrecords.py
# Out:
# 2023-02-06 12:45:12.540493: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-06 12:45:13.504905: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-06 12:45:13.505006: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-06 12:45:13.505025: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Total examples: 495, train examples: 396.
# Traceback (most recent call last):
#   File "pascal_xml_to_tfrecords.py", line 129, in <module>
#     convert_to_tfrecords(annotated_images_dir, label_map_path, train_records_file, val_records_file)
#   File "pascal_xml_to_tfrecords.py", line 118, in convert_to_tfrecords
#     with tf.python_io.TFRecordWriter(train_records_file) as train_writer, tf.python_io.TFRecordWriter(val_records_file) as val_writer:
# AttributeError: module 'tensorflow' has no attribute 'python_io'

# %%
# !python exporter_main_v2.py --input_type image_tensor --pipeline_config_path /content/drive/MyDrive/tf_workspace/training_demo/models/first_resnet101_v1_nn/pipeline.config --trained_checkpoint_dir /content/drive/MyDrive/tf_workspace/training_demo/models/first_resnet101_v1_nn --output_directory /content/drive/MyDrive/tf_workspace/training_demo/exported-models/resnet101_38k_steps
# Out:
# 2023-02-06 05:50:58.477757: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-06 05:50:59.721864: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-06 05:50:59.721975: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-06 05:50:59.722009: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2023-02-06 05:51:03.839622: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# W0206 05:51:08.591265 140036485749824 deprecation.py:350] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0206 05:51:08.655580 140036485749824 deprecation.py:623] From /usr/local/lib/python3.8/dist-packages/tensorflow/python/autograph/impl/api.py:458: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f5c40123190>, because it is not built.
# W0206 05:51:34.816301 140036485749824 save_impl.py:66] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7f5c40123190>, because it is not built.
# W0206 05:52:08.027476 140036485749824 save.py:271] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalClassHead_layer_call_fn while saving (showing 5 of 329). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/tf_workspace/training_demo/exported-models/resnet101_38k_steps/saved_model/assets
# I0206 05:52:18.129211 140036485749824 builder_impl.py:797] Assets written to: /content/drive/MyDrive/tf_workspace/training_demo/exported-models/resnet101_38k_steps/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to /content/drive/MyDrive/tf_workspace/training_demo/exported-models/resnet101_38k_steps/pipeline.config
# I0206 05:52:19.749815 140036485749824 config_util.py:253] Writing pipeline config file to /content/drive/MyDrive/tf_workspace/training_demo/exported-models/resnet101_38k_steps/pipeline.config

# %% [markdown]
# ## Test Exported Model

# %%
cd /content/drive/MyDrive/tf_workspace/training_demo
# Out:
# /content/drive/MyDrive/tf_workspace/training_demo

# %%
"""
Object Detection (On Image) From TF2 Saved Model
=====================================
"""

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'    # Suppress TensorFlow logging (1)
import pathlib
import tensorflow as tf
import cv2
import argparse
from google.colab.patches import cv2_imshow

# Enable GPU dynamic memory allocation
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# PROVIDE PATH TO IMAGE DIRECTORY
IMAGE_PATH = '/content/drive/MyDrive/tf_workspace/training_demo/images/verify/'

STORAGE_LOCATION = '/content/drive/MyDrive/tf_workspace/training_demo/viewedImages'


# PROVIDE PATH TO MODEL DIRECTORY
PATH_TO_MODEL_DIR = '/content/drive/MyDrive/tf_workspace/training_demo/exported-models/first_custom_resnet101'

# PROVIDE PATH TO LABEL MAP
PATH_TO_LABELS = '/content/drive/MyDrive/tf_workspace/training_demo/annotations/label_map.pbtxt'

# PROVIDE THE MINIMUM CONFIDENCE THRESHOLD
MIN_CONF_THRESH = float(0.60)

# LOAD THE MODEL

import time
import random
from object_detection.utils import label_map_util
from object_detection.utils import visualization_utils as viz_utils

PATH_TO_SAVED_MODEL = PATH_TO_MODEL_DIR + "/saved_model"

print('Loading model...', end='')
start_time = time.time()

# LOAD SAVED MODEL AND BUILD DETECTION FUNCTION
detect_fn = tf.saved_model.load(PATH_TO_SAVED_MODEL)

end_time = time.time()
elapsed_time = end_time - start_time
print('Done! Took {} seconds'.format(elapsed_time))

# LOAD LABEL MAP DATA FOR PLOTTING

category_index = label_map_util.create_category_index_from_labelmap(PATH_TO_LABELS,
                                                                    use_display_name=True)

import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')   # Suppress Matplotlib warnings

def load_image_into_numpy_array(path):
    """Load an image from file into a numpy array.
    Puts image into numpy array to feed into tensorflow graph.
    Note that by convention we put it into a numpy array with shape
    (height, width, channels), where channels=3 for RGB.
    Args:
      path: the file path to the image
    Returns:
      uint8 numpy array with shape (img_height, img_width, 3)
    """
    return np.array(Image.open(path))

fileList = os.listdir(IMAGE_PATH)
random.shuffle(fileList)

fileCount = 0

for files in fileList:
  fileCount +=1
  if(fileCount > 10):
    break
  IMAGE_PATHS = os.path.join(IMAGE_PATH, files)
  print('Running inference for {}... '.format(IMAGE_PATHS), end='')
  fileCheck = os.fsdecode(IMAGE_PATHS)
  if(fileCheck.endswith(".xml")):
    fileCount -=1
    continue
  image = cv2.imread(IMAGE_PATHS)
  image = cv2.resize(image, dsize=(640, 640), interpolation=cv2.INTER_CUBIC)

  image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image_expanded = np.expand_dims(image_rgb, axis=0)

  # The input needs to be a tensor, convert it using `tf.convert_to_tensor`.
  input_tensor = tf.convert_to_tensor(image)
  # The model expects a batch of images, so add an axis with `tf.newaxis`.
  input_tensor = input_tensor[tf.newaxis, ...]

  # input_tensor = np.expand_dims(image_np, 0)
  detections = detect_fn(input_tensor)

  # All outputs are batches tensors.
  # Convert to numpy arrays, and take index [0] to remove the batch dimension.
  # We're only interested in the first num_detections.
  num_detections = int(detections.pop('num_detections'))
  detections = {key: value[0, :num_detections].numpy()
                for key, value in detections.items()}
  detections['num_detections'] = num_detections

  # detection_classes should be ints.
  detections['detection_classes'] = detections['detection_classes'].astype(np.int64)

  image_with_detections = image.copy()

  # SET MIN_SCORE_THRESH BASED ON YOU MINIMUM THRESHOLD FOR DETECTIONS
  viz_utils.visualize_boxes_and_labels_on_image_array(
        image_with_detections,
        detections['detection_boxes'],
        detections['detection_classes'],
        detections['detection_scores'],
        category_index,
        use_normalized_coordinates=True,
        max_boxes_to_draw=200,
        min_score_thresh=0.1,
        agnostic_mode=False)

  print(detections['detection_classes'])
  print(detections['detection_scores'])
  #print('Done')
  # DISPLAYS OUTPUT IMAGE
  #data = Image.fromarray(image_with_detections)
  #data.save(os.path.join("/content/drive/MyDrive/tf_workspace/training_demo/images/classified",files))
  #print(type(image_with_detections))
  cv2_imshow(image_with_detections)
  # CLOSES WINDOW ONCE KEY IS PRESSED
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Download Model

# %%
cd /content/drive/MyDrive/tf_workspace/training/pre-trained-models
# Out:
# /content/drive/MyDrive/tf_workspace/training/pre-trained-models

# %%
# !wget http://download.tensorflow.org/models/object_detection/tf2/20200713/centernet_hg104_512x512_coco17_tpu-8.tar.gz
# Out:
# --2023-02-01 19:43:31--  http://download.tensorflow.org/models/object_detection/tf2/20200713/centernet_hg104_512x512_coco17_tpu-8.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 173.194.194.128, 2607:f8b0:4001:c10::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|173.194.194.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1426099846 (1.3G) [application/x-tar]
# Saving to: ‘centernet_hg104_512x512_coco17_tpu-8.tar.gz’
#
# centernet_hg104_512 100%[===================>]   1.33G  96.6MB/s    in 18s
#
# 2023-02-01 19:43:49 (77.2 MB/s) - ‘centernet_hg104_512x512_coco17_tpu-8.tar.gz’ saved [1426099846/1426099846]

# %%
# !tar -xvf centernet_hg104_512x512_coco17_tpu-8.tar.gz
# Out:
# centernet_hg104_512x512_coco17_tpu-8/
# centernet_hg104_512x512_coco17_tpu-8/checkpoint/
# centernet_hg104_512x512_coco17_tpu-8/checkpoint/ckpt-0.data-00000-of-00001
# centernet_hg104_512x512_coco17_tpu-8/checkpoint/checkpoint
# centernet_hg104_512x512_coco17_tpu-8/checkpoint/ckpt-0.index
# centernet_hg104_512x512_coco17_tpu-8/pipeline.config
# centernet_hg104_512x512_coco17_tpu-8/saved_model/
# centernet_hg104_512x512_coco17_tpu-8/saved_model/saved_model.pb
# centernet_hg104_512x512_coco17_tpu-8/saved_model/assets/
# centernet_hg104_512x512_coco17_tpu-8/saved_model/variables/
# centernet_hg104_512x512_coco17_tpu-8/saved_model/variables/variables.data-00000-of-00001
# centernet_hg104_512x512_coco17_tpu-8/saved_model/variables/variables.index

# %%
import tensorflow as tf
from functools import partial
import matplotlib.pyplot as plt

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()
    print("Device:", tpu.master())
    strategy = tf.distribute.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print("Number of replicas:", strategy.num_replicas_in_sync)
AUTOTUNE = tf.data.AUTOTUNE
GCS_PATH = "gs://kds-b38ce1b823c3ae623f5691483dbaa0f0363f04b0d6a90b63cf69946e"
BATCH_SIZE = 8
IMAGE_SIZE = [720, 720]
FILENAMES = tf.io.gfile.glob("/content/drive/MyDrive/tf_workspace/training_demo/annotations/train.record")
split_ind = int(0.9 * len(FILENAMES))
TRAINING_FILENAMES, VALID_FILENAMES = FILENAMES[:split_ind], FILENAMES[split_ind:]

TEST_FILENAMES = tf.io.gfile.glob("/content/drive/MyDrive/tf_workspace/training_demo/annotations/test.record")
print("Train TFRecord Files:", len(TRAINING_FILENAMES))
print("Validation TFRecord Files:", len(VALID_FILENAMES))
print("Test TFRecord Files:", len(TEST_FILENAMES))
# Out:
# Number of replicas: 1
# ['/content/drive/MyDrive/tf_workspace/training_demo/annotations/train.record']
# Train TFRecord Files: 0
# Validation TFRecord Files: 1
# Test TFRecord Files: 1
