# %% [markdown]
# # Settings

# %%
#!pip install Pillow==9.0.0

# %%
import os
from tqdm.auto import tqdm
import shutil
import tensorflow as tf
import matplotlib.pyplot as plt
import cv2 as cv
from google.colab.patches import cv2_imshow
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from PIL import Image
import numpy as np
from skimage import transform
from PIL import Image, ImageDraw
from numpy import asarray, arange, mgrid, ndarray
from numpy.lib.stride_tricks import sliding_window_view
from dataclasses import dataclass
import multiprocessing
import math
import random
import sys
import copy
import time

# %%
#sys.path.insert(0,'/content/drive/MyDrive/tf_workspace/Python_Code/custom_CNN.py')

# %%
#from custom_CNN import Custom_CNN

# %%
def Custom_CNN(input_shape):
  #device_name = tf.test.gpu_device_name()
  #if device_name != '/device:GPU:0':
  #  print(
  #      '\n\nThis error most likely means that this notebook is not '
  #      'configured to use a GPU.  Change this in Notebook Settings via the '
  #      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  #  raise SystemError('GPU device not found')
  #tf.device('/device:GPU:0')
  model = tf.keras.models.Sequential([
      # Input layer
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
      
      # Preprocessing
      tf.keras.layers.RandomRotation(factor=1, fill_mode='reflect', interpolation='bilinear', seed=None, fill_value=0.0, ),
      tf.keras.layers.RandomFlip(),
      
      # Feature extraction
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.AveragePooling2D(pool_size=(2, 2)),
      
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.AveragePooling2D(pool_size=(2, 2)),
      
      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.AveragePooling2D(pool_size=(2, 2)),

      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.GlobalAveragePooling2D(),
      
      # Classifier
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(1024, activation='relu'),
      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Dense(4, activation='softmax')
  ])
  return model

# %%
def Custom_Small_CNN_2(input_shape):
  #device_name = tf.test.gpu_device_name()
  #if device_name != '/device:GPU:0':
  #  print(
  #      '\n\nThis error most likely means that this notebook is not '
  #      'configured to use a GPU.  Change this in Notebook Settings via the '
  #      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  #  raise SystemError('GPU device not found')
  #tf.device('/device:GPU:0')
  model = tf.keras.models.Sequential([
      # Input layer
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
      
      # Preprocessing
      #tf.keras.layers.RandomRotation(factor=1, fill_mode='reflect', interpolation='bilinear', seed=None, fill_value=0.0, ),
      #tf.keras.layers.RandomFlip(),
      
      # Feature extraction
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.AveragePooling2D(pool_size=(2, 2)),

      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.AveragePooling2D(pool_size=(2, 2)),
      
      # Classifier
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(256, activation='relu'),
      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Dense(4, activation='softmax')
  ])
  return model

# %%
def Custom_Small_CNN_v3(input_shape):
  #device_name = tf.test.gpu_device_name()
  #if device_name != '/device:GPU:0':
  #  print(
  #      '\n\nThis error most likely means that this notebook is not '
  #      'configured to use a GPU.  Change this in Notebook Settings via the '
  #      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  #  raise SystemError('GPU device not found')
  #tf.device('/device:GPU:0')
  model = tf.keras.models.Sequential([
      # Input layer
      tf.keras.layers.Conv2D(32, (7, 7), activation='relu', input_shape=input_shape),
      
      # Preprocessing
      #tf.keras.layers.RandomRotation(factor=1, fill_mode='reflect', interpolation='bilinear', seed=None, fill_value=0.0, ),
      #tf.keras.layers.RandomFlip(),
      
      # Feature extraction
      tf.keras.layers.Conv2D(32, (7, 7), activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Conv2D(64, (7, 7), activation='relu'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.AveragePooling2D(pool_size=(2, 2)),

      tf.keras.layers.Conv2D(64, (7, 7), activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.AveragePooling2D(pool_size=(2, 2)),
      
      # Classifier
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(256, activation='relu'),
      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Dense(4, activation='softmax')
  ])
  return model

# %%
def Custom_Small_CNN(input_shape):
  #device_name = tf.test.gpu_device_name()
  #if device_name != '/device:GPU:0':
  #  print(
  #      '\n\nThis error most likely means that this notebook is not '
  #      'configured to use a GPU.  Change this in Notebook Settings via the '
  #      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  #  raise SystemError('GPU device not found')
  #tf.device('/device:GPU:0')
  model = tf.keras.models.Sequential([
      # Input layer
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
      
      # Preprocessing
      #tf.keras.layers.RandomRotation(factor=1, fill_mode='reflect', interpolation='bilinear', seed=None, fill_value=0.0, ),
      #tf.keras.layers.RandomFlip(),
      
      # Feature extraction
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
      tf.keras.layers.Dropout(0.25),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.AveragePooling2D(pool_size=(2, 2)),
      
      # Classifier
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(256, activation='relu'),
      tf.keras.layers.Dropout(0.5),
      tf.keras.layers.Dense(4, activation='softmax')
  ])
  return model

# %%
def NASNetMobile_CNN(input_shape):
  baseModel = tf.keras.applications.nasnet.NASNetMobile(include_top=False, input_shape=input_shape)
  #baseModel = SeResNeXT(include_top=False, input_shape=input_shape)

  flat1 = tf.keras.layers.Flatten()(baseModel.layers[-1].output)
  class1 = tf.keras.layers.Dense(256, activation='relu')(flat1)
  output = tf.keras.layers.Dense(4, activation='softmax')(class1)

  model = tf.keras.Model(inputs = baseModel.inputs, outputs = output)
  return model

# %%
targetSizeElement = 64
target_size = (targetSizeElement,targetSizeElement)
target_input_size = (targetSizeElement,targetSizeElement, 3)

analyzeImageLocation = "/content/drive/MyDrive/tf_workspace/training_cnn/images/validation"

model = Custom_Small_CNN_v3(target_input_size)
CALLBACK_PATH = "/content/drive/MyDrive/tf_workspace/CNN/Evaluate/Custom_small_v3/checkpoints/cp-0050.ckpt"

DATASET_PATH = "/content/drive/MyDrive/tf_workspace/training_cnn/images/validation"#"/content/drive/MyDrive/tf_workspace/training_cnn/testImage"
IMAGE_PATH = "/content/drive/MyDrive/tf_workspace/training_cnn/testImage/bee/bee_1.jpg"
DRAWN_IMG_PATH = "/content/drive/MyDrive/tf_workspace/Sliding_Window/"

COLOR_BEE = [1,1,0] #Yellow
COLOR_INSECT = [0,1,0]  #Green
COLOR_BUMBLEBEE = [0,0,1]   #Blue
COLOR_VESPULA = [1,0,0] #Red

# %% [markdown]
# # Helper Functions

# %%
testing = ImageDataGenerator(rescale=1/255)
testing_dataset = testing.flow_from_directory(analyzeImageLocation,target_size=target_size, shuffle=False)
# Out:
# Found 1325 images belonging to 4 classes.

# %%
def convertAndStoreTfModel(model, pathToStore):
  model.trainable = False
  model.compile(optimizer='adam', metrics=["accuracy"], loss=tf.keras.losses.CategoricalCrossentropy())
  model.load_weights(CALLBACK_PATH).expect_partial()
  converter = tf.lite.TFLiteConverter.from_keras_model(model)
  tflite_model = converter.convert()
  # Save the model.
  with open(f'{pathToStore}/model.tflite', 'wb') as f:
    f.write(tflite_model)

# %%
def PredictionTests():
    targetSizeElement = 256
    target_size = (targetSizeElement,targetSizeElement)
    testing = ImageDataGenerator(rescale=1/255)
    testing_dataset = testing.flow_from_directory(DATASET_PATH,target_size=target_size, shuffle=False)
    #model = getModel()
    #model = getExternModel()
    model.compile(optimizer='adam', metrics=["accuracy"], loss=tf.keras.losses.CategoricalCrossentropy())
    model.load_weights(CALLBACK_PATH).expect_partial()
    #model.load_weights(CALLBACK_PATH_EXTERN).expect_partial()
    
    print(model.evaluate(testing_dataset))
    
    return

# %%
def drawRectangle(image:np.ndarray, shape:tuple, lineWidth = 1, color = [1,0,0]):
    (xmin, ymin, xmax, ymax) = shape
    #print(image[0][0])
    #draw horizontal lines
    #cv.line(image, (xmin,ymin), (xmax,ymax), 255, 2)
    image[:, ymin:ymin+lineWidth, xmin:xmax] = color
    image[:, ymax-lineWidth:ymax, xmin:xmax] = color

    #draw vertical lines
    image[:, ymin:ymax, xmin:xmin+lineWidth] = color
    image[:, ymin:ymax, xmax-lineWidth:xmax] = color
    #image[xmax:xmax+lineWidth, ymin:ymax, :] = [1,0,0]

    return image

# %%
def splitLoadImage(filename: str, sectionSize=200) -> ndarray:
    image = Image.open(filename)
    xSize = image.size[0] / sectionSize
    ySize = image.size[1] / sectionSize
    xSize = math.ceil(xSize)
    ySize = math.ceil(ySize)
    image = image.resize(size=(sectionSize*xSize, sectionSize*ySize), resample=Image.Resampling.NEAREST)
    np_data = np.array(image).astype('float32')/255
    np_image = np.expand_dims(np_data, axis=0)
    return np_image

# %%
def getImageSection(image:np.ndarray, shape:tuple):
    (xmin, ymin, xmax, ymax) = shape
    return image[:, ymin:ymax, xmin:xmax]

# %%
def convertToImage(image)->Image:
    formatter = (image[0] * 255 / np.max(image[0])).astype('uint8')
    image = Image.fromarray(formatter)
    return image

# %%
def slidingWindowSection(model, image, stepSize = 0.5, windowSize = (256,256)):
  pass

# %%
class ImageSection:
  xMin:int
  yMin: int
  xMax: int
  yMax: int
  colorCode:list

  def __init__(self,imagePosition:tuple, color:list):
    self.xMin, self.yMin, self.xMax,  self.yMax = imagePosition
    self.colorCode= color
  
  def getBoxPosition(self)->tuple:
    return (self.xMin, self.yMin, self.xMax,  self.yMax)
  
  def updateCordinates(self, positions:tuple):
    xMin, yMin, xMax, yMax = positions
    if(xMin < self.xMin): self.xMin = xMin
    if(yMin < self.yMin): self.yMin = yMin
    if(xMax > self.xMax): self.xMax = xMax
    if(yMax > self.yMax): self.yMax = yMax

def drawBoxes(boxList:list[ImageSection], image):
  for element in boxList:
    image = drawRectangle(image, element.getBoxPosition(), color=element.colorCode)
  return image

def removeBoxOverlap(boxLister:list[ImageSection], stepSize = 0.5, windowSize = (256,256))->list[ImageSection]:
  boxList = copy.deepcopy(boxLister)
  xBoxOverlapAmount, yBoxOverlapAmount = windowSize
  xBoxOverlapAmount =  xBoxOverlapAmount*stepSize
  yBoxOverlapAmount =  yBoxOverlapAmount*stepSize
  for box_1 in boxList:
    for box2Index, box_2 in enumerate(boxList):
      if(box_1 is box_2 or box_1.colorCode != box_2.colorCode): continue
      if(comparePositionValues(box_1.xMin, box_2.xMin,xBoxOverlapAmount)  or
         comparePositionValues(box_1.yMin, box_2.yMin,yBoxOverlapAmount)  or
         comparePositionValues(box_1.xMax, box_2.xMax,xBoxOverlapAmount)  or
         comparePositionValues(box_1.yMax, box_2.yMax,yBoxOverlapAmount)
      ):
        box_1.updateCordinates(box_2.getBoxPosition())
        boxList.pop(box2Index)
  return boxList

def comparePositionValues(pos1, pos2, stepDifference=0):
  posDiff = pos1-pos2
  if(posDiff < 0): posDiff = posDiff*-1
  if(posDiff <=stepDifference):
    return True
  return False

# %%
def slidingWindow(stepSize = 0.5, windowSize = (256,256)):
    model.trainable = False
    model.compile(optimizer='adam', metrics=["accuracy"], loss=tf.keras.losses.CategoricalCrossentropy())
    model.load_weights(CALLBACK_PATH).expect_partial()

    image = splitLoadImage(IMAGE_PATH, sectionSize=512)
    for index in range(3,4):
      xWindowSize, yWindowSize = windowSize

      xWindowSize = xWindowSize/index
      yWindowSize = yWindowSize/index
      #print(image.shape)
      #testImage = convertToImage(image)
      #imageSection = getImageSection(image, (0,0,100,100))#drawRectangle(image,(0,0,100,100))
      #testImage2 = convertToImage(image)

      #testImage.show()
      #print(imageSection.shape)
      #testImage2.show()

      #print(image.shape)
      _, yLen, xLen, _ = image.shape
      xStepLen = (xWindowSize*stepSize)
      yStepLen = (yWindowSize*stepSize)
      xSteps = int(xLen/xStepLen)-int(1/stepSize)+1
      ySteps = int(yLen/yStepLen)-int(1/stepSize)+1

      #drawRectangle(image, (200,200,400,400), color=COLOR_BEE)
      #drawRectangle(image, (200,400,400,600), color=COLOR_VESPULA)
      #testImg = getImageSection(image, (200,200,400,400))
      
      #testImage2 = convertToImage(np_image)
      #testImage2.show()

      #model = getModel()
      #model = getExternModel()
      
      image_with_boxes = copy.deepcopy(image)
      boxList = []

      #return
      start = time.time()
      for yStepPart in range(0,ySteps):
          for xStepPart in range(0,xSteps):
              imagePosition = (int(xStepLen*xStepPart),int(yStepLen*yStepPart), int(xStepLen*xStepPart+xWindowSize),int(yStepLen*yStepPart+yWindowSize))
              imageSection = getImageSection(image, imagePosition)
              result = analyzeImage(model, imageSection)
              if(result == None): continue
              classIndex, classPercentage = result
              if(classIndex != None and classPercentage > 0.95):
                  if(classIndex == 0):
                      boxList.append(ImageSection(imagePosition, color=COLOR_BEE))
                      #image_with_boxes = drawRectangle(image_with_boxes, imagePosition, color=COLOR_BEE)
                  if(classIndex == 1):
                      boxList.append(ImageSection(imagePosition, color=COLOR_BUMBLEBEE))
                      #image_with_boxes = drawRectangle(image_with_boxes, imagePosition, color=COLOR_BUMBLEBEE)
                  if(classIndex == 2):
                      boxList.append(ImageSection(imagePosition, color=COLOR_INSECT))
                      #image_with_boxes = drawRectangle(image_with_boxes, imagePosition, color=COLOR_INSECT)
                  if(classIndex == 3):
                      boxList.append(ImageSection(imagePosition, color=COLOR_VESPULA))
                      #image_with_boxes = drawRectangle(image_with_boxes, imagePosition, color=COLOR_VESPULA)
      end = time.time()
      stringTime = time.strftime("%H:%M:%S", time.gmtime(end-start))
      print(f"Predict time for training is {stringTime} seconds")
      #boxList = removeBoxOverlap(boxList)
      image_with_boxes= drawBoxes(boxList, image_with_boxes)
      testImage2 = convertToImage(image_with_boxes)
      testImage2.save(f"{DRAWN_IMG_PATH}testImg({index}).jpg")
      print(f"Finished Step {index}")
    print(f"Hole Image Predicted as {analyzeImage(model,image)}")
    return image, boxList
    #testImage2.show()

# %%
def tfLiteSlidingWindow(model_path, stepSize = 0.5, windowSize = (256,256)):
    interpreter = tf.lite.Interpreter(model_path=model_path)
    model = interpreter.get_signature_runner('serving_default')

    image = splitLoadImage(IMAGE_PATH, sectionSize=512)
    for index in range(3,4):
      xWindowSize, yWindowSize = windowSize

      xWindowSize = xWindowSize/index
      yWindowSize = yWindowSize/index
      #print(image.shape)
      #testImage = convertToImage(image)
      #imageSection = getImageSection(image, (0,0,100,100))#drawRectangle(image,(0,0,100,100))
      #testImage2 = convertToImage(image)

      #testImage.show()
      #print(imageSection.shape)
      #testImage2.show()

      #print(image.shape)
      _, yLen, xLen, _ = image.shape
      xStepLen = (xWindowSize*stepSize)
      yStepLen = (yWindowSize*stepSize)
      xSteps = int(xLen/xStepLen)-int(1/stepSize)+1
      ySteps = int(yLen/yStepLen)-int(1/stepSize)+1

      #drawRectangle(image, (200,200,400,400), color=COLOR_BEE)
      #drawRectangle(image, (200,400,400,600), color=COLOR_VESPULA)
      #testImg = getImageSection(image, (200,200,400,400))
      
      #testImage2 = convertToImage(np_image)
      #testImage2.show()

      #model = getModel()
      #model = getExternModel()
      
      image_with_boxes = copy.deepcopy(image)
      boxList = []

      #return
      start = time.time()
      for yStepPart in range(0,ySteps):
          for xStepPart in range(0,xSteps):
              imagePosition = (int(xStepLen*xStepPart),int(yStepLen*yStepPart), int(xStepLen*xStepPart+xWindowSize),int(yStepLen*yStepPart+yWindowSize))
              imageSection = getImageSection(image, imagePosition)
              result = analyzeFTLiteImage(model, imageSection)
              if(result == None): continue
              classIndex, classPercentage = result
              if(classIndex != None and classPercentage > 0.95):
                  if(classIndex == 0):
                      boxList.append(ImageSection(imagePosition, color=COLOR_BEE))
                      #image_with_boxes = drawRectangle(image_with_boxes, imagePosition, color=COLOR_BEE)
                  if(classIndex == 1):
                      boxList.append(ImageSection(imagePosition, color=COLOR_BUMBLEBEE))
                      #image_with_boxes = drawRectangle(image_with_boxes, imagePosition, color=COLOR_BUMBLEBEE)
                  if(classIndex == 2):
                      boxList.append(ImageSection(imagePosition, color=COLOR_INSECT))
                      #image_with_boxes = drawRectangle(image_with_boxes, imagePosition, color=COLOR_INSECT)
                  if(classIndex == 3):
                      boxList.append(ImageSection(imagePosition, color=COLOR_VESPULA))
                      #image_with_boxes = drawRectangle(image_with_boxes, imagePosition, color=COLOR_VESPULA)
      end = time.time()
      stringTime = time.strftime("%H:%M:%S", time.gmtime(end-start))
      print(f"Predict time for training is {stringTime} seconds")
      start = time.time()
      boxList = removeBoxOverlap(boxList)
      end = time.time()
      stringTime = time.strftime("%H:%M:%S", time.gmtime(end-start))
      print(f"Box time for training is {stringTime} seconds")
      start = time.time()
      image_with_boxes= drawBoxes(boxList, image_with_boxes)
      end = time.time()
      stringTime = time.strftime("%H:%M:%S", time.gmtime(end-start))
      print(f"Draw time for training is {stringTime} seconds")
      testImage2 = convertToImage(image_with_boxes)
      testImage2.save(f"{DRAWN_IMG_PATH}testImg({index}).jpg")
      print(f"Finished Step {index}")
    print(f"Hole Image Predicted as {analyzeFTLiteImage(model,image)}")
    #testImage2.show()

# %%
#TODO: Should be class count indipendent
def analyzeImage(model, image)->int:
    image = transform.resize(image, (1,64, 64, 3))
    #print(image.shape)
    val = model.predict(image)
    #print(val)
    #print(val)
    detectionList = val.tolist()
    if(detectionList[0] == None): return (None, None)
    for index, element in enumerate(detectionList[0]):
        if (element >= 0.5):
            return (index,element)

# %%
#TODO: Should be class count indipendent
def analyzeFTLiteImage(tfLiteModel, image)->int:
    image = transform.resize(image, (1,256, 256, 3))
    #print(image.shape)
    val = tfLiteModel(conv2d_9_input=image)['dense_3']
    #print(val)
    #print(val)
    detectionList = val.tolist()
    if(detectionList[0] == None): return (None, None)
    for index, element in enumerate(detectionList[0]):
        if (element >= 0.5):
            return (index,element)

# %%
def getClass(detectionList):
  if(detectionList[0] == None): return (None, None)
  for index, element in enumerate(detectionList[0]):
      if (element >= 0.5):
          return (index,element)

# %%
def splitLoadImage(filename: str, sectionSize=200) -> ndarray:
    image = Image.open(filename)
    xSize = image.size[0] / sectionSize
    ySize = image.size[1] / sectionSize
    xSize = math.ceil(xSize)
    ySize = math.ceil(ySize)
    image = image.resize(size=(sectionSize*xSize, sectionSize*ySize), resample=Image.NEAREST)
    np_data = np.array(image).astype('float32')/255
    np_image = np.expand_dims(np_data, axis=0)
    return np_image

# %% [markdown]
# # Computation

# %%
interpreter = tf.lite.Interpreter(model_path="/content/drive/MyDrive/tf_workspace/CNN/TFLite/Custom_v3/quant_model.tflite")

# %%
interpreter.get_signature_list()
# Out:
# {'serving_default': {'inputs': ['conv2d_9_input'], 'outputs': ['dense_3']}}

# %%
classify_lite = interpreter.get_signature_runner('serving_default')
classify_lite

# %%
image = splitLoadImage(IMAGE_PATH, sectionSize=256)
new_img = transform.resize(image, (1,256, 256, 3))
predictions_lite = classify_lite(conv2d_63_input=new_img)
print(predictions_lite)
# Out:
# {'dense_15': array([[9.5514590e-01, 3.5867430e-05, 4.3399315e-02, 1.4189781e-03]],
#       dtype=float32)}

# %%
print(predictions_lite['dense_15'])
# Out:
# [[9.5514590e-01 3.5867430e-05 4.3399315e-02 1.4189781e-03]]

# %%
startTime1 = time.time()
imageLoaded, boxList = slidingWindow(stepSize=0.05,windowSize=(256,256))#PredictionTests()
endTime1 = time.time()
#startTime2 = time.time()
#tfLiteSlidingWindow(model_path="/content/drive/MyDrive/tf_workspace/CNN/TFLite/Custom_v3/quant_model.tflite",stepSize=0.5,windowSize=(256,256))
#endTime2 = time.time()

timeRequired = endTime1-startTime1
stringTime = time.strftime("%H:%M:%S", time.gmtime(timeRequired))
print(f"Required time for training is {stringTime} seconds")
#timeRequired = endTime2-startTime2
#stringTime = time.strftime("%H:%M:%S", time.gmtime(timeRequired))
#print(f"Required time for training is {stringTime} seconds")
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# ...
# 1/1 [==============================] - 0s 107ms/step
# ...
# ...
# 1/1 [==============================] - 0s 44ms/step

# %%
image_with_boxes = copy.deepcopy(imageLoaded)

# %%
boxListComp = removeBoxOverlap(boxList)
image_with_boxes= drawBoxes(boxListComp, image_with_boxes)
testImage = convertToImage(image_with_boxes)
testImage.show()

# %%
#boxListComp = removeBoxOverlap(boxList)
image_with_boxes= drawBoxes(boxListComp, image_with_boxes)
testImage = convertToImage(image_with_boxes)
testImage.show()

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_quant_model = converter.convert()
with open(f'/content/drive/MyDrive/tf_workspace/CNN/TFLite/Custom_v3/quant_model.tflite', 'wb') as f:
    f.write(tflite_quant_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 10). These functions will not be directly callable after loading.

# %%
convertAndStoreTfModel(model, "/content/drive/MyDrive/tf_workspace/CNN/TFLite/Custom_v3")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 10). These functions will not be directly callable after loading.

# %%
tfLiteSlidingWindow("/content/drive/MyDrive/tf_workspace/CNN/TFLite/Custom_v3/model.tflite")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-6de7b8d3a2f4> in <cell line: 1>()
# ----> 1 tfLiteSlidingWindow("/content/drive/MyDrive/tf_workspace/CNN/TFLite/Custom_v3/model.tflite")
#
# <ipython-input-101-9e52e0d195f8> in tfLiteSlidingWindow(modelPath, stepSize, windowSize)
#      10
#      11     # input_details[0]['index'] = the index which accepts the input
# ---> 12     interpreter.set_tensor(input_details[0]['index'], [new_img])
#      13
#      14     # run the inference
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/lite/python/interpreter.py in set_tensor(self, tensor_index, value)
#     694       ValueError: If the interpreter could not set the tensor.
#     695     """
# --> 696     self._interpreter.SetTensor(tensor_index, value)
#     697
#     698   def resize_tensor_input(self, input_index, tensor_size, strict=False):
#
# ...

# %%
#model.trainable = False
model.compile(optimizer='adam', metrics=["accuracy"], loss=tf.keras.losses.CategoricalCrossentropy())
model.load_weights(CALLBACK_PATH).expect_partial()

# %%
#model.evaluate(testing_dataset)

# %%
x_part, y_part = next(testing_dataset)
x_part[0]
for element in x_part:
  print(analyzeImage(model, element))

# %%
image = splitLoadImage(IMAGE_PATH, sectionSize=512)

# %%
print(analyzeImage(model, image))

# %% [markdown]
# # Results
